# %% [markdown]
# <a href="https://colab.research.google.com/github/WibowoAdiSaputro/Tugas-ScrappingSerpApi_0020/blob/main/TugasTextMining(100review).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_maps",
  "q": "steak",
  "ll": "@-7.0245542,110.3470242,12z",
  "type": "search",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
local_results = results["local_results"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Eatmeat Steak House',
#   'place_id': 'ChIJWYj5T66McC4RHa11Eq-lbvA',
#   'data_id': '0x2e708cae4ff98859:0xf06ea5af1275ad1d',
#   'data_cid': '17324966987888438557',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.981696599999999,
#    'longitude': 110.43589949999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cae4ff98859%3A0xf06ea5af1275ad1d%218m2%213d-6.981696599999999%214d110.43589949999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 3,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C9P+89C, Jl. Rejosari VII, Rejosari, Semarang Timur, Semarang City, Central Java 50125, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=UeSCBzPwdAhGcVhkBOLUhg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=334.76016&pitch=0&thumbfov=100'},
#  {'position': 2,
#   'title': 'Steaky Steak Sriwijaya Semarang',
#   'place_id': 'ChIJzxVGooKLcC4RiTjb6yLY4hA',
#   'data_id': '0x2e708b82a24615cf:0x10e2d822ebdb3889',
#   'data_cid': '1216772493840955529',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.999720699999999,
#    'longitude': 110.42240489999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b82a24615cf%3A0x10e2d822ebdb3889%218m2%213d-6.999720699999999%214d110.42240489999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 84,
#   'type': 'Steak house',
#   'address': 'Jl. Sriwijaya No.16, Tegalsari, Kec. Candisari, Kota Semarang, Jawa Tengah 50614, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11:30AM–9PM',
#    'wednesday': '11:30AM–9PM',
#    'thursday': '11:30AM–9PM',
#    'friday': '11:30AM–9PM',
#    'saturday': '11:30AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11:30AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN-q1TtYM39l_8VnZ8yPjC0wkfL-Drzgbr8TDN1=w80-h141-k-no'},
#  {'position': 3,
#   'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'place_id': 'ChIJ_UbCzYOLcC4R_zy6lNDVVhU',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'data_cid': '1537651414618750207',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0185885, 'longitude': 110.41940249999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b83cdc246fd%3A0x1556d5d094ba3cff%218m2%213d-7.0185885%214d110.41940249999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 2731,
#   'price': '$$',
#   'type': 'Steak house',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Candisari, Semarang City, Central Java 50232, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–11PM',
#    'sunday': '11AM–10PM',
#    'monday': '11AM–10PM'},
#   'phone': '+62 895-3549-91000',
#   'website': 'https://holycowsteak.com/',
#   'description': 'Restoran yg khusus menyajikan steak. Tempat makan yg menyajikan aneka pilihan daging berkualitas untuk steak, menerima panggilan kermh.',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPqPu4bqhe7bEBipPvmc-2Yi3pWSiXw7nfe4gOe=w163-h92-k-no'},
#  {'position': 4,
#   'title': 'STEAK ON THE STREET',
#   'place_id': 'ChIJ3bcbz7CNcC4Rm3lhyM7tzU0',
#   'data_id': '0x2e708db0cf1bb7dd:0x4dcdedcec861799b',
#   'data_cid': '5606398583527012763',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0396816, 'longitude': 110.4933362},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b%218m2%213d-7.0396816%214d110.4933362&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 5,
#   'reviews': 3,
#   'type': 'Steak house',
#   'address': 'Jl. Pucang Gading Raya No.104, Pucanggading, Batursari, Kec. Mranggen, Kabupaten Demak, Jawa Tengah 59567, Indonesia',
#   'open_state': 'Opens soon ⋅ 1PM',
#   'hours': 'Opens soon ⋅ 1PM',
#   'operating_hours': {'tuesday': '1–9PM',
#    'wednesday': '1–9PM',
#    'thursday': '1–9PM',
#    'friday': '1–9PM',
#    'saturday': '1–9PM',
#    'sunday': '1–9PM',
#    'monday': '1–9PM'},
#   'service_options': {'dine_in': True,
#    'drive_through': True,
#    'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoBouqPTUZvcPWyRMDJ6iiMkumZwei1Sz9KKmR=w163-h92-k-no'},
#  {'position': 5,
#   'title': 'Taman Sari Grilled Steak',
#   'place_id': 'ChIJB2uu93-LcC4RHEItlgp_X78',
#   'data_id': '0x2e708b7ff7ae6b07:0xbf5f7f0a962d421c',
#   'data_cid': '13789880267477697052',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0158051, 'longitude': 110.4256154},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c%218m2%213d-7.0158051%214d110.4256154&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 44,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'XCMG+M6H, Jl. Sisingamangaraja, Wonotingal, Kec. Candisari, Kota Semarang, Jawa Tengah 50525, Indonesia',
#   'open_state': 'Closed ⋅ Opens 4:30PM',
#   'hours': 'Closed ⋅ Opens 4:30PM',
#   'operating_hours': {'tuesday': '4:30–10PM',
#    'wednesday': '4:30–10PM',
#    'thursday': '4:30–10PM',
#    'friday': '4:30–10PM',
#    'saturday': '4:30–10PM',
#    'sunday': '4:30–10PM',
#    'monday': '4:30–10PM'},
#   'phone': '+62 812-2880-0077',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMIBpI0E2BiBfiDjiV0wgfgbl-PrO_ZnHpWlyuD=w122-h92-k-no'},
#  {'position': 6,
#   'title': 'Ins Steak House',
#   'place_id': 'ChIJw30Hzn-McC4Rw6s_u3UE-q8',
#   'data_id': '0x2e708c7fce077dc3:0xaffa0475bb3fabc3',
#   'data_cid': '12680452604514249667',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0174904, 'longitude': 110.4274169},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3%218m2%213d-7.0174904%214d110.4274169&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 6,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Dr. Wahidin No.92, Karanganyar Gunung, Candisari, Semarang City, Central Java 50253, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11AM–9PM'},
#   'phone': '+62 24 8310732',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEa34w2Qslkr037xNsf0EN_nTSyKcy6VhPcFIs=w80-h142-k-no'},
#  {'position': 7,
#   'title': 'So STEAK KENDAL',
#   'place_id': 'ChIJUXBXDGRdcC4R9CYZ14nMBzw',
#   'data_id': '0x2e705d640c577051:0x3c07cc89d71926f4',
#   'data_cid': '4325650859503986420',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9267803, 'longitude': 110.2071981},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e705d640c577051%3A0x3c07cc89d71926f4%218m2%213d-6.9267803%214d110.2071981&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 142,
#   'type': 'Restaurant',
#   'address': 'Kersan, Kebondalem, Kec. Kendal, Kabupaten Kendal, Jawa Tengah 51318, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': 'Closed'},
#   'phone': '+62 813-2949-2745',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPTe_Z-l8NMLqs2MSEHqNmY3KNuoLLrgmKu_C2d=w92-h92-k-no'},
#  {'position': 8,
#   'title': 'Star Steak',
#   'place_id': 'ChIJ5Z3wNmKLcC4RW933sUSOrjU',
#   'data_id': '0x2e708b6236f09de5:0x35ae8e44b1f7dd5b',
#   'data_cid': '3868185555652566363',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.010968999999999, 'longitude': 110.396046},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b%218m2%213d-7.010968999999999%214d110.396046&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 660,
#   'type': 'Steak house',
#   'address': 'Jl. Lamongan Raya No.12, Bendan Ngisor, Gajahmungkur, Semarang City, Central Java 50321, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '10AM–10PM',
#    'wednesday': '10AM–10PM',
#    'thursday': '10AM–10PM',
#    'friday': '10AM–10PM',
#    'saturday': '10AM–10PM',
#    'sunday': '10AM–10PM',
#    'monday': '10AM–10PM'},
#   'phone': '+62 858-8031-8858',
#   'website': 'https://starsteak-steakhouse.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP53s4hhDWTGrSUpbs4z7h5UrHVYdg07T3NkS7K=w194-h92-k-no'},
#  {'position': 9,
#   'title': 'Chicken Steak Crispy',
#   'place_id': 'ChIJ63e8DKaLcC4RI1wT2vMWTQA',
#   'data_id': '0x2e708ba60cbc77eb:0x4d16f3da135c23',
#   'data_cid': '21698809798286371',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9959221, 'longitude': 110.42092559999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba60cbc77eb%3A0x4d16f3da135c23%218m2%213d-6.9959221%214d110.42092559999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 15,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Pleburan Barat No.42, Pleburan, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50241, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNud-mXw04ejp8ArcZJXB_RDM2QpW7QnSGFjroI=w80-h142-k-no'},
#  {'position': 10,
#   'title': "MR FAT'S CHEESE STEAK",
#   'place_id': 'ChIJYQlJbsaMcC4Rl8VTYaRKD1g',
#   'data_id': '0x2e708cc66e490961:0x580f4aa46153c597',
#   'data_cid': '6345372469856290199',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9857739, 'longitude': 110.45514759999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cc66e490961%3A0x580f4aa46153c597%218m2%213d-6.9857739%214d110.45514759999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 22,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jalan Soekarno Hatta No.12 (Omah Jones), Kel. Tlogosari kulon , Kec. Gayamsari, Tlogosari Kulon, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50166, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 812-2622-7972',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Dg3XR_w3rqfIAftwT24KiA&cb_client=search.gws-prod.gps&w=80&h=92&yaw=188.40073&pitch=0&thumbfov=100'},
#  {'position': 11,
#   'title': 'beef steak spicy bolapelangi',
#   'place_id': 'ChIJL2aVRzuLcC4R6S8By3vLEaY',
#   'data_id': '0x2e708b3b4795662f:0xa611cb7bcb012fe9',
#   'data_cid': '11966569417447387113',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9809377999999995,
#    'longitude': 110.4244296},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b3b4795662f%3A0xa611cb7bcb012fe9%218m2%213d-6.9809377999999995%214d110.4244296&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': '2C9F+JQF, Gabahan, Semarang Tengah, Semarang City, Central Java 50135, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=A1zOu47mxt1eIuUUUf_Zrg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=19.593874&pitch=0&thumbfov=100'},
#  {'position': 12,
#   'title': 'Hans Steak',
#   'place_id': 'ChIJKwIlMECLcC4R6I8KGGzSs8w',
#   'data_id': '0x2e708b403025022b:0xccb3d26c180a8fe8',
#   'data_cid': '14750364566270152680',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9958234, 'longitude': 110.404715},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b403025022b%3A0xccb3d26c180a8fe8%218m2%213d-6.9958234%214d110.404715&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.8,
#   'reviews': 10,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C33+MVG, Jalan Kaligarang Raya, Barusari, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50244, Indonesia',
#   'open_state': 'Open ⋅ Closes 11PM',
#   'hours': 'Open ⋅ Closes 11PM',
#   'operating_hours': {'tuesday': '12–11PM',
#    'wednesday': '12–11PM',
#    'thursday': '12–11PM',
#    'friday': '12–11PM',
#    'saturday': '12–11PM',
#    'sunday': '12–11PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPm0c2HrgmNhi4-EjJIYQB2RgisVEa0V9XYXyEA=w99-h92-k-no'},
#  {'position': 13,
#   'title': 'jjsteak_therealsteak',
#   'place_id': 'ChIJpcSY1MmNcC4RqRhOAODVGpA',
#   'data_id': '0x2e708dc9d498c4a5:0x901ad5e0004e18a9',
#   'data_cid': '10383847048910608553',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9973417, 'longitude': 110.45581039999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9%218m2%213d-6.9973417%214d110.45581039999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 55,
#   'type': 'Steak house',
#   'address': 'Jl. Supriyadi No.20a, Kalicari, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50198, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–10PM',
#    'sunday': '11AM–10PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMSZ-QYnnSQC0scxmtfSHeMYXzvVaZMfMjU079o=w80-h106-k-no'},
#  {'position': 14,
#   'title': 'Royal Steak Citraland Mall',
#   'place_id': 'ChIJt_wE5ViLcC4RjATI-B32Jyo',
#   'data_id': '0x2e708b58e504fcb7:0x2a27f61df8c8048c',
#   'data_cid': '3037667082273031308',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.988728, 'longitude': 110.42369599999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b58e504fcb7%3A0x2a27f61df8c8048c%218m2%213d-6.988728%214d110.42369599999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.9,
#   'reviews': 13,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Mal Ciputra, Jalan simpang lima nomor 1, Citraland mall lantai 2, Food fair counter 11, Pekunden, Kec. Semarang Tengah, Kota Semarang, Jawa Tengah 50134, Indonesia',
#   'open_state': 'Open ⋅ Closes 9:30PM',
#   'hours': 'Open ⋅ Closes 9:30PM',
#   'operating_hours': {'tuesday': '9:30AM–9:30PM',
#    'wednesday': '9:30AM–9:30PM',
#    'thursday': '9:30AM–9:30PM',
#    'friday': '9:30AM–9:30PM',
#    'saturday': '9:30AM–9:30PM',
#    'sunday': '9:30AM–9:30PM',
#    'monday': '9:30AM–9:30PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPB23lKZAwvxQCERaBpIuz6rg-bNEMap3zWF1hm=w122-h92-k-no'},
#  {'position': 15,
#   'title': 'KhoKhu STEAK',
#   'place_id': 'ChIJ7WCwtwCMcC4REPjCbTl0_EM',
#   'data_id': '0x2e708c00b7b060ed:0x43fc74396dc2f810',
#   'data_cid': '4898918284675708944',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0232432, 'longitude': 110.4644659},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c00b7b060ed%3A0x43fc74396dc2f810%218m2%213d-7.0232432%214d110.4644659&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 229,
#   'type': 'Steak house',
#   'address': 'Jl. Gemah Jaya I, Kedungmundu, Tembalang, Semarang City, Central Java 50273, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '8AM–9PM',
#    'wednesday': '8AM–9PM',
#    'thursday': '8AM–9PM',
#    'friday': '8AM–9PM',
#    'saturday': '8AM–9PM',
#    'sunday': '8AM–9PM',
#    'monday': '8AM–9PM'},
#   'phone': '+62 878-7878-6241',
#   'website': 'https://www.facebook.com/khokhusteak.10414',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOCNTiV5n_8Ijv_Wrtqd1y2h9Xf_iCYutRzi6c=w204-h92-k-no'},
#  {'position': 16,
#   'title': 'Omah Steak',
#   'place_id': 'ChIJJYEA34uMcC4RdP6Tzg9iJu4',
#   'data_id': '0x2e708c8bdf008125:0xee26620fce93fe74',
#   'data_cid': '17160511250171690612',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0251882, 'longitude': 110.4602877},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c8bdf008125%3A0xee26620fce93fe74%218m2%213d-7.0251882%214d110.4602877&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': 'Jl. Kedungmundu No.19F, Kedungmundu, Kec. Tembalang, Kota Semarang, Jawa Tengah 50276, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=bbUS742SFXF7cOV2EGSCoQ&cb_client=search.gws-prod.gps&w=80&h=92&yaw=174.13599&pitch=0&thumbfov=100'},
#  {'position': 17,
#   'title': 'Steaky Steak Gajah Raya',
#   'place_id': 'ChIJk2lVeTqNcC4RbMlmYH1BwT0',
#   'data_id': '0x2e708d3a79556993:0x3dc1417d6066c96c',
#   'data_cid': '4449909913562827116',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9884702, 'longitude': 110.44835099999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708d3a79556993%3A0x3dc1417d6066c96c%218m2%213d-6.9884702%214d110.44835099999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 22,
#   'type': 'Steak house',
#   'address': 'Jl. Gajah Raya No.26 A, Siwalan, Kec. Gayamsari, Kota Semarang, Jawa Tengah 50262, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '12–9PM',
#    'wednesday': '12–9PM',
#    'thursday': '12–9PM',
#    'friday': '12–9PM',
#    'saturday': '12–9PM',
#    'sunday': '12–9PM',
#    'monday': '12–9PM'},
#   'phone': '+62 813-1923-4527',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOIkKZJDSPvlcWivR3-17C5g3zLTmLNBLkey-ic=w80-h142-k-no'},
#  {'position': 18,
#   'title': 'Omah Steak Qu',
#   'place_id': 'ChIJafZKkqiLcC4RfPs6n-p2Hgo',
#   'data_id': '0x2e708ba8924af669:0xa1e76ea9f3afb7c',
#   'data_cid': '729150939746466684',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9817195, 'longitude': 110.395702},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba8924af669%3A0xa1e76ea9f3afb7c%218m2%213d-6.9817195%214d110.395702&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 298,
#   'type': 'Steak house',
#   'address': 'Jl. Jenderal Sudirman, RT.001/RW.003, Cabean, Semarang Barat, Semarang City, Central Java 50141, Indonesia',
#   'open_state': 'Open ⋅ Closes 8PM',
#   'hours': 'Open ⋅ Closes 8PM',
#   'operating_hours': {'tuesday': '11:30AM–8PM',
#    'wednesday': '11:30AM–8PM',
#    'thursday': '11:30AM–8PM',
#    'friday': '11:30AM–8PM',
#    'saturday': '11:30AM–8PM',
#    'sunday': 'Closed',
#    'monday': '11:30AM–8PM'},
#   'phone': '+62 895-3270-76017',
#   'website': 'https://omah-steak-qu.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True,
#    'curbside_pickup': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipODaJ7qKrkRQMMtO9N0Y0e06RxjglhYzAlnwWty=w181-h92-k-no'},
#  {'position': 19,
#   'title': 'STAR STEAK',
#   'place_id': 'ChIJDbUrhDyJcC4RRPeD1oXmJ7g',
#   'data_id': '0x2e70893c842bb50d:0xb827e685d683f744',
#   'data_cid': '13269828289574467396',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0701481, 'longitude': 110.4219492},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e70893c842bb50d%3A0xb827e685d683f744%218m2%213d-7.0701481%214d110.4219492&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 318,
#   'type': 'Restaurant',
#   'address': 'Jl. Jati Raya No.25, Pedalangan, Kec. Banyumanik, Kota Semarang, Jawa Tengah 50268, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 858-8031-8858',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMYzqzTp4ybC6UGEn60Wbulm978VIWKlIw50Rgx=w199-h92-k-no'},
#  {'position': 20,
#   'title': 'Super steak jangli',
#   'place_id': 'ChIJgy7B1e2LcC4RhVj37ck6yEo',
#   'data_id': '0x2e708bedd5c12e83:0x4ac83ac9edf75885',
#   'data_cid': '5388621593104046213',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0275238, 'longitude': 110.424275},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708bedd5c12e83%3A0x4ac83ac9edf75885%218m2%213d-7.0275238%214d110.424275&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Fast food restaurant',
#   'address': 'Jl. Kesatrian rt003 No.h15, RW.008, Jatingaleh, Kec. Candisari, Kota Semarang, Jawa Tengah, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Alyg8hChtfhw9ZG82vRj_A&cb_client=search.gws-prod.gps&w=80&h=92&yaw=314.3858&pitch=0&thumbfov=100'}]

# %%
#Posisi1
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b83cdc246fd:0x1556d5d094ba3cff",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
results
# Out:
# {'search_metadata': {'id': '633bcdd887a0ee8404f6079f',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/593f485fa2ed72dc/633bcdd887a0ee8404f6079f.json',
#   'created_at': '2022-10-04 06:08:24 UTC',
#   'processed_at': '2022-10-04 06:08:24 UTC',
#   'google_maps_reviews_url': 'https://www.google.com/async/reviewDialog?hl=en&async=feature_id:0x2e708b83cdc246fd:0x1556d5d094ba3cff,sort_by:,next_page_token:,associated_topic:,_fmt:pc',
#   'raw_html_file': 'https://serpapi.com/searches/593f485fa2ed72dc/633bcdd887a0ee8404f6079f.html',
#   'total_time_taken': 0.67},
#  'search_parameters': {'engine': 'google_maps_reviews',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'hl': 'en'},
#  'place_info': {'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Semarang City, Central Java, Indonesia',
#   'rating': 4.5,
#   'reviews': 2731},
#  'topics': [{'keyword': 'quality service', 'mentions': 27, 'id': '/m/0g5b032'},
#   {'keyword': 'message', 'mentions': 15, 'id': '/m/0g52jn4'},
#   {'keyword': 'champions', 'mentions': 14, 'id': '/m/03s7vj'},
#   {'keyword': 'standards', 'mentions': 10, 'id': '/m/025shgm'},
#   {'keyword': 'maturity', 'mentions': 9, 'id': '/m/02w5_kh'},
#   {'keyword': 'playground', 'mentions': 9, 'id': '/m/01h_1n'},
#   {'keyword': 'tongue', 'mentions': 9, 'id': '/m/0fjkt'},
#   {'keyword': 'carnivore', 'mentions': 7, 'id': '/m/05glqkd'},
#   {'keyword': 'salinity', 'mentions': 5, 'id': '/m/06pzy'},
#   {'keyword': 'relative price', 'mentions': 5, 'id': '/m/09sb2x'}],
#  'reviews': [{'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURzNHZYenZnRRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIDs4vXzvgE%7CCgsI4qbj8gUQuLqZVQ%7C?hl=en-US',
#    'user': {'name': 'Nirmala Hidajati',
#     'link': 'https://www.google.com/maps/contrib/112405339408404308244?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegQIARBB',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu8RBbhB1Jw1rOt1aYmacg1-62s7PG0-Aqb6jlPG=s40-c-c0x00000000-cc-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 253,
#     'photos': 460},
#    'rating': 5.0,
#    'date': '2 years ago',
#    'snippet': 'The best steak house that I ever eaten. I ordered rib eye with mushroom sauce and mash potato and green bean. Rib eye is welldone but still juicy and smooth. Mushroom sauce is so nice creamy but not heavy. The greenbean is seasoned good. The waitress is friendly and very helpfull. The place is cozy and nice for take lunch or dinner with family, coworkers, and friends.',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipOHgBz3JgkHGxQ_mOZg4tf3SuUc1eDZl5a72QHN=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipOrXokRvwzjib9_t-hhT8lmEK55CzTGtoW16xhB=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipOHYJmsIFxvCEvk0oF0tk6lIvgzIRXhAkLZs-8q=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMC5MiYssBPomGqlWP5kOz9GdEQil7L1L5D0bWH=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipODqcgUUStAmLCJEvqci4fuxdHU6fDN1DJtVkiC=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMdSd6PkYyPt6LsXW2K3IGRFJV9fZ7qLHC10dc6=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMsiwt6y8ugod6AH6o_uP1YYwz_1THOTJgzqxkW=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipPaS0ZNo9HXUSnxN5d5Ln4iNakEWxTZnrFa7R0o=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMSNT7zVWpwP_-4w8liRE9SsJOP2pc2oEuoONlY=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUQyNElPOXVnRRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgID24IO9ugE%7CCgsIxsLFkwYQkOHidg%7C?hl=en-US',
#    'user': {'name': 'Chendy Christian',
#     'link': 'https://www.google.com/maps/contrib/114004558080434670991?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegQIARBh',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu9Ow2LKgzSpffvbQStWSBv_WZC3wnjoHCfw4TkSjA=s40-c-c0x00000000-cc-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 193,
#     'photos': 420},
#    'rating': 4.0,
#    'date': '5 months ago',
#    'snippet': "They didn't provide some mustard and other things now ? Just sambal sauce ?",
#    'likes': 2,
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipMWirf3hJBWvl8CMRE5xV6SBMXnARJNslEt4vzj=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURJNUlyQ3lRRRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIDI5IrCyQE%7CCgsIveuH_wUQqMbpWg%7C?hl=en-US',
#    'user': {'name': 'Arno “Rockerss07” Febrianto',
#     'link': 'https://www.google.com/maps/contrib/100866602831094410117?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegQIARB-',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu99XSdZqRcyGhi2gtQ_d7uE--5dqJ5aX-jLToa0=s40-c-c0x00000000-cc-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 145,
#     'photos': 699},
#    'rating': 5.0,
#    'date': 'a year ago',
#    'snippet': 'Great place for family dinners, medium price. Great 🥩 steak Back again one year later , order 3 tenderloin and two wagyu tenderloin valleys . 22/12/2020 Not crowded because of covid19 pandemic .',
#    'likes': 1,
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipOd5ngy6gc2NvHz1WDDLep4wMsMxZm72mK_LVxz=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMSPf10u_8gKxWw5VY2R5vHQDfWcVqd_xZYz3Xa=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipNMPy8xt-e69YGyOuLie351JY0g_3tKCQktYfyZ=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipOFpfDNvFnqwVMgdMAhcKYUSE1qfZoNO4Ygaed5=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURNaVBpZ21BRRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIDMiPigmAE%7CCgsIwbrT7wUQ4MPjUQ%7C?hl=en-US',
#    'user': {'name': 'Kiki Maliana',
#     'link': 'https://www.google.com/maps/contrib/111693540074088091231?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARCZAQ',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu-eVUNfeZT1mwW-0oBwMqRwe3QjUt8MrAWiFWr_DQ=s40-c-c0x00000000-cc-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 205,
#     'photos': 349},
#    'rating': 4.0,
#    'date': '2 years ago',
#    'snippet': "One of famous steak house in Semarang, have a cozy place and many facilities like mushola, rest room and large parking area for car and motorcycle, the steak is very good but when i was order well done Legendary steak, it's not well done cooked.. i hope next time it will be attention",
#    'likes': 3,
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipN2qSOwuT-5l_xfkoXDfqiCQFEqnnlEg4Wh_9Dn=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMLQ8fDlQi44-5vDfVsieHF0Qo29M_DOA0ro9Sk=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipNynHasvr4i3t6t3uCPV4SNHuKw8yhAqsGf9PlR=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMqHvVqnzUpfrzoZgQwAswe20BIqv0LJ51aNi8R=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipPpBkctI2mTdj-xHHyVdYUK4QKpUXHk4LxgUNTQ=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipN_KNHKkpfFs0n8iyD5Gi3lTPPBLJ2CAoGlPdJO=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMAzXx1Ec-MDNPDlus-J7yT2rJ2Y7wC_9LF45vN=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipPMHZ6nCabItU6EahcnKIM2JAT6SYaJCAPmUqQI=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMMwfCj_Rs_iD8Ca6g7pfPQ4Ecml7sFTNgcHMez=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipNownrJ-OiyTx7FunfZGZdhM1nv35tm0MaWZcMC=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipPwdPZgmW-fcuina3dQSsz82-UbJcx-IXyneRij=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUNtNThXT3V3RRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgICm58WOuwE%7CCgwIq4mmlQYQ6JHGpwI%7C?hl=en-US',
#    'user': {'name': 'Ignasius Bagus Satrio Suhardiyono',
#     'link': 'https://www.google.com/maps/contrib/101958983773145629539?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARC7AQ',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu_oZhyLCyx12MBnHCn7-YilGQEzH4gx4TQeuGxkjg=s40-c-c0x00000000-cc-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 110,
#     'photos': 496},
#    'rating': 4.0,
#    'date': '3 months ago',
#    'snippet': "$$$$ Price range: around IDR 25k - 250k 5 🌟 for the service, but 4 🌟 for the taste. The hospitality of the staffs is very good. I ordered medium steak, but unfortunately it's more well done than medium."},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUQwb092cmZBEAE!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgID0oOvrfA%7CCgwIxbGl7QUQyPaMhQE%7C?hl=en-US',
#    'user': {'name': 'Arafah Khoirul',
#     'link': 'https://www.google.com/maps/contrib/112198875132408142186?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARDRAQ',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ALm5wu3LsopOe6Qh823ITF-gepw36kiS-FtxIloKL5ky=s40-c-c0x00000000-cc-rp-mo-ba4-br100',
#     'local_guide': True,
#     'reviews': 43,
#     'photos': 59},
#    'rating': 4.0,
#    'date': '2 years ago',
#    'snippet': 'The place was quite comfy. They have spacious parking lot. Im not an expert in food so for me the taste was quite tasty. I ordered medium steak. It was a bit raw but still ok. I liked the mashed potato. They still have birhtday promo and thats good',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipPEpbH6_MDT719ZBsimWX9G8Iq4B04XrvDhSh5c=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipN810lFy28fYbGDTwNcq3nI-1VJPf4uJqGkjU4E=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURJak9HSVlnEAE!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIDIjOGIYg%7CCgwIk5GD4QUQ9qqi1QI%7C?hl=en-US',
#    'user': {'name': 'Wulan Dhesi',
#     'link': 'https://www.google.com/maps/contrib/110700629646254225021?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARDqAQ',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu81ZUgIv6H9EcD_BXHhQGMTbqffCmyoGeMHlXZ5HA=s40-c-c0x00000000-cc-rp-mo-ba2-br100',
#     'local_guide': True,
#     'reviews': 19,
#     'photos': 26},
#    'rating': 4.0,
#    'date': '3 years ago',
#    'snippet': "Thought it's the best steak in town. Why? It has many menus you can choose with fair price. Starting from 45K rupiah to 200K. And it serves fresh meat with savoury taste. I came here several times. Buddy's tenderloin steak which made of Japanese meat is my favourite. The meat is soft, juicy, and no fat. It cost 99K. You can ask more sauces for free but only for 3times. Whereas, my husband ordered Australian prime sirloin. It's juicy, soft, but it has some fat. He said, mine was better. It cost 99K also. So, with their high quality meat and its fair price, I would recommend you to come here. Luckily, if you come here during on your birthday, you'll get an ice cream!",
#    'likes': 1,
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipOTrNgi7HnI-R6yKYoYvr2ah9w-oY9KljcCYK-b=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipM2RLBLW3v2oaVWj9kPw7Vmj8HST9YZwumciVpC=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURDdjRYMXl3RRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIDCv4X1ywE%7CCgwI2MSq_AUQuIqf_AI%7C?hl=en-US',
#    'user': {'name': 'Rezha August',
#     'link': 'https://www.google.com/maps/contrib/111749723791639010495?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARCDAg',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu97DoCaZvfhogjfnzj52BUuyNhL2H96t8ZrU9ZE=s40-c-c0x00000000-cc-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 104,
#     'photos': 609},
#    'rating': 4.0,
#    'date': 'a year ago',
#    'snippet': 'the holycow sc goes excellent with the spinach rather than w/ the steak.black pepper sc no argue!love it!reasonable price,lovable wait staff.but to me using frying pan as the serving plate is a big No! A bit challenging to cut the steak while the knife kept colliding the tall body of the pan (serving plate). And kinda think the ambience can be improved in order to enjoy the steak more.',
#    'likes': 1,
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipMEz82m1NQ8DrBU9xi19zD5gRUvNS6xWuwFh6zO=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMfX3VAiRGPjYWGn_0l3kxXgwKKYqBG4w3IFXEt=w100-h100-p-n-k-no']},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUMyd3ViMHdRRRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIC2wub0wQE%7CCgsIz9jpkgYQ-KPMCA%7C?hl=en-US',
#    'user': {'name': 'Fajar Aribowo',
#     'link': 'https://www.google.com/maps/contrib/108767822275272269843?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARCcAg',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu_vbYG4trJHLlsI2VKhBYOTO1t64ZkS7qYL2gGxHg=s40-c-c0x00000000-cc-rp-mo-br100',
#     'reviews': 2},
#    'rating': 1.0,
#    'date': '5 months ago',
#    'snippet': 'I order for medium-well steak, and i get Rare, Twice, even after re-grilled. And there are any a lot of muscle in a tenderloin. Really?Its very dissapointing'},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURNdnR6WDh3RRAB!2m1!1s0x0:0x1556d5d094ba3cff!3m1!1s2@1:CIHM0ogKEICAgIDMvtzX8wE%7CCgsI0Let8AUQ4MbACQ%7C?hl=en-US',
#    'user': {'name': 'Flo Renshi',
#     'link': 'https://www.google.com/maps/contrib/107957783851029582763?hl=en-US&sa=X&ved=2ahUKEwiWhvfN9MX6AhW5AjQIHYHuCSMQvvQBegUIARCyAg',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ACNPEu_pO1eB2hSgBtChoU66TeLCu11etJQE9uICO1dFrw=s40-c-c0x00000000-cc-rp-mo-ba4-br100',
#     'local_guide': True,
#     'reviews': 87,
#     'photos': 28},
#    'rating': 4.0,
#    'date': '2 years ago',
#    'snippet': 'Good service, good meat quality. Only too bad some menus already sold out.',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipPTONBm12KLO4zlkzdYjSYmCUETKwyKlG5cvy6V=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipPxl-jEOnjp9wPcpN7PevIl8GEQAJ5gJsCPzL6w=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipN6r1bSiQFUn5VmRuQJGWXFMh_6FEGK-v0Ah1b3=w100-h100-p-n-k-no']}],
#  'serpapi_pagination': {'next': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en&next_page_token=CAESBkVnSUlDZw%3D%3D',
#   'next_page_token': 'CAESBkVnSUlDZw=='}}

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  reviews = results["reviews"][i]["snippet"]
  print(reviews)
# Out:
# 5.0
# The best steak house that I ever eaten. I ordered rib eye with mushroom sauce and mash potato and green bean. Rib eye is welldone but still juicy and smooth. Mushroom sauce is so nice creamy but not heavy. The greenbean is seasoned good. The waitress is friendly and very helpfull. The place is cozy and nice for take lunch or dinner with family, coworkers, and friends.
# 4.0
# They didn't provide some mustard and other things now ? Just sambal sauce ?
# 5.0
# Great place for family dinners, medium price. Great 🥩 steak Back again one year later , order 3 tenderloin and two wagyu tenderloin valleys . 22/12/2020 Not crowded because of covid19 pandemic .
# 4.0
# 4.0
# (Translated by Google) A good steak for its class, the meat is also tender (Original) Steak yang enak untuk kelas nya, daging nya juga empuk
# 5.0
# (Translated by Google) The rib soup taste, really ok(Original)Rasa sop iga nya, ok banget
# 5.0
# (Translated by Google) Steak lover's must try....addicted guaranteed..🤩🤩🤩🤩 (Original) Steak lover's musti coba....dijamin ketagihan..🤩🤩🤩🤩
# 5.0
# (Translated by Google) Eating this steak from back when I was dating maybe even more than 10 years ago..salisbury is the best ... even though the street vendors can't be ignored ... I think I was a former chef or restaurant work first hehhe ... steak costs around 28 to 52 .. there is also rib soup..n spagethi (Original) Makan steak ini dr dulu jaman pacaran mgkn lbh dr 10 tahun lalu..salisbury is the best...walaupun kaki lima rasa ga boleh disepelin..enak aku rasa mantan chef atau kerja resto deh dulu hehhe..harga steak sekitar 28 sampai 52..ada juga sop iga..n spagethi
# 5.0
# 👍🏻👍🏻

# %%
#Posisi4
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e705d640c577051:0x3c07cc89d71926f4",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Eatmeat Steak House',
#   'place_id': 'ChIJWYj5T66McC4RHa11Eq-lbvA',
#   'data_id': '0x2e708cae4ff98859:0xf06ea5af1275ad1d',
#   'data_cid': '17324966987888438557',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.981696599999999,
#    'longitude': 110.43589949999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cae4ff98859%3A0xf06ea5af1275ad1d%218m2%213d-6.981696599999999%214d110.43589949999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 3,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C9P+89C, Jl. Rejosari VII, Rejosari, Semarang Timur, Semarang City, Central Java 50125, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=UeSCBzPwdAhGcVhkBOLUhg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=334.76016&pitch=0&thumbfov=100'},
#  {'position': 2,
#   'title': 'Steaky Steak Sriwijaya Semarang',
#   'place_id': 'ChIJzxVGooKLcC4RiTjb6yLY4hA',
#   'data_id': '0x2e708b82a24615cf:0x10e2d822ebdb3889',
#   'data_cid': '1216772493840955529',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.999720699999999,
#    'longitude': 110.42240489999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b82a24615cf%3A0x10e2d822ebdb3889%218m2%213d-6.999720699999999%214d110.42240489999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 84,
#   'type': 'Steak house',
#   'address': 'Jl. Sriwijaya No.16, Tegalsari, Kec. Candisari, Kota Semarang, Jawa Tengah 50614, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11:30AM–9PM',
#    'wednesday': '11:30AM–9PM',
#    'thursday': '11:30AM–9PM',
#    'friday': '11:30AM–9PM',
#    'saturday': '11:30AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11:30AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN-q1TtYM39l_8VnZ8yPjC0wkfL-Drzgbr8TDN1=w80-h141-k-no'},
#  {'position': 3,
#   'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'place_id': 'ChIJ_UbCzYOLcC4R_zy6lNDVVhU',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'data_cid': '1537651414618750207',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0185885, 'longitude': 110.41940249999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b83cdc246fd%3A0x1556d5d094ba3cff%218m2%213d-7.0185885%214d110.41940249999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 2731,
#   'price': '$$',
#   'type': 'Steak house',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Candisari, Semarang City, Central Java 50232, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–11PM',
#    'sunday': '11AM–10PM',
#    'monday': '11AM–10PM'},
#   'phone': '+62 895-3549-91000',
#   'website': 'https://holycowsteak.com/',
#   'description': 'Restoran yg khusus menyajikan steak. Tempat makan yg menyajikan aneka pilihan daging berkualitas untuk steak, menerima panggilan kermh.',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPqPu4bqhe7bEBipPvmc-2Yi3pWSiXw7nfe4gOe=w163-h92-k-no'},
#  {'position': 4,
#   'title': 'STEAK ON THE STREET',
#   'place_id': 'ChIJ3bcbz7CNcC4Rm3lhyM7tzU0',
#   'data_id': '0x2e708db0cf1bb7dd:0x4dcdedcec861799b',
#   'data_cid': '5606398583527012763',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0396816, 'longitude': 110.4933362},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b%218m2%213d-7.0396816%214d110.4933362&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 5,
#   'reviews': 3,
#   'type': 'Steak house',
#   'address': 'Jl. Pucang Gading Raya No.104, Pucanggading, Batursari, Kec. Mranggen, Kabupaten Demak, Jawa Tengah 59567, Indonesia',
#   'open_state': 'Opens soon ⋅ 1PM',
#   'hours': 'Opens soon ⋅ 1PM',
#   'operating_hours': {'tuesday': '1–9PM',
#    'wednesday': '1–9PM',
#    'thursday': '1–9PM',
#    'friday': '1–9PM',
#    'saturday': '1–9PM',
#    'sunday': '1–9PM',
#    'monday': '1–9PM'},
#   'service_options': {'dine_in': True,
#    'drive_through': True,
#    'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoBouqPTUZvcPWyRMDJ6iiMkumZwei1Sz9KKmR=w163-h92-k-no'},
#  {'position': 5,
#   'title': 'Taman Sari Grilled Steak',
#   'place_id': 'ChIJB2uu93-LcC4RHEItlgp_X78',
#   'data_id': '0x2e708b7ff7ae6b07:0xbf5f7f0a962d421c',
#   'data_cid': '13789880267477697052',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0158051, 'longitude': 110.4256154},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c%218m2%213d-7.0158051%214d110.4256154&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 44,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'XCMG+M6H, Jl. Sisingamangaraja, Wonotingal, Kec. Candisari, Kota Semarang, Jawa Tengah 50525, Indonesia',
#   'open_state': 'Closed ⋅ Opens 4:30PM',
#   'hours': 'Closed ⋅ Opens 4:30PM',
#   'operating_hours': {'tuesday': '4:30–10PM',
#    'wednesday': '4:30–10PM',
#    'thursday': '4:30–10PM',
#    'friday': '4:30–10PM',
#    'saturday': '4:30–10PM',
#    'sunday': '4:30–10PM',
#    'monday': '4:30–10PM'},
#   'phone': '+62 812-2880-0077',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMIBpI0E2BiBfiDjiV0wgfgbl-PrO_ZnHpWlyuD=w122-h92-k-no'},
#  {'position': 6,
#   'title': 'Ins Steak House',
#   'place_id': 'ChIJw30Hzn-McC4Rw6s_u3UE-q8',
#   'data_id': '0x2e708c7fce077dc3:0xaffa0475bb3fabc3',
#   'data_cid': '12680452604514249667',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0174904, 'longitude': 110.4274169},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3%218m2%213d-7.0174904%214d110.4274169&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 6,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Dr. Wahidin No.92, Karanganyar Gunung, Candisari, Semarang City, Central Java 50253, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11AM–9PM'},
#   'phone': '+62 24 8310732',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEa34w2Qslkr037xNsf0EN_nTSyKcy6VhPcFIs=w80-h142-k-no'},
#  {'position': 7,
#   'title': 'So STEAK KENDAL',
#   'place_id': 'ChIJUXBXDGRdcC4R9CYZ14nMBzw',
#   'data_id': '0x2e705d640c577051:0x3c07cc89d71926f4',
#   'data_cid': '4325650859503986420',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9267803, 'longitude': 110.2071981},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e705d640c577051%3A0x3c07cc89d71926f4%218m2%213d-6.9267803%214d110.2071981&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 142,
#   'type': 'Restaurant',
#   'address': 'Kersan, Kebondalem, Kec. Kendal, Kabupaten Kendal, Jawa Tengah 51318, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': 'Closed'},
#   'phone': '+62 813-2949-2745',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPTe_Z-l8NMLqs2MSEHqNmY3KNuoLLrgmKu_C2d=w92-h92-k-no'},
#  {'position': 8,
#   'title': 'Star Steak',
#   'place_id': 'ChIJ5Z3wNmKLcC4RW933sUSOrjU',
#   'data_id': '0x2e708b6236f09de5:0x35ae8e44b1f7dd5b',
#   'data_cid': '3868185555652566363',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.010968999999999, 'longitude': 110.396046},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b%218m2%213d-7.010968999999999%214d110.396046&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 660,
#   'type': 'Steak house',
#   'address': 'Jl. Lamongan Raya No.12, Bendan Ngisor, Gajahmungkur, Semarang City, Central Java 50321, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '10AM–10PM',
#    'wednesday': '10AM–10PM',
#    'thursday': '10AM–10PM',
#    'friday': '10AM–10PM',
#    'saturday': '10AM–10PM',
#    'sunday': '10AM–10PM',
#    'monday': '10AM–10PM'},
#   'phone': '+62 858-8031-8858',
#   'website': 'https://starsteak-steakhouse.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP53s4hhDWTGrSUpbs4z7h5UrHVYdg07T3NkS7K=w194-h92-k-no'},
#  {'position': 9,
#   'title': 'Chicken Steak Crispy',
#   'place_id': 'ChIJ63e8DKaLcC4RI1wT2vMWTQA',
#   'data_id': '0x2e708ba60cbc77eb:0x4d16f3da135c23',
#   'data_cid': '21698809798286371',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9959221, 'longitude': 110.42092559999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba60cbc77eb%3A0x4d16f3da135c23%218m2%213d-6.9959221%214d110.42092559999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 15,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Pleburan Barat No.42, Pleburan, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50241, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNud-mXw04ejp8ArcZJXB_RDM2QpW7QnSGFjroI=w80-h142-k-no'},
#  {'position': 10,
#   'title': "MR FAT'S CHEESE STEAK",
#   'place_id': 'ChIJYQlJbsaMcC4Rl8VTYaRKD1g',
#   'data_id': '0x2e708cc66e490961:0x580f4aa46153c597',
#   'data_cid': '6345372469856290199',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9857739, 'longitude': 110.45514759999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cc66e490961%3A0x580f4aa46153c597%218m2%213d-6.9857739%214d110.45514759999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 22,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jalan Soekarno Hatta No.12 (Omah Jones), Kel. Tlogosari kulon , Kec. Gayamsari, Tlogosari Kulon, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50166, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 812-2622-7972',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Dg3XR_w3rqfIAftwT24KiA&cb_client=search.gws-prod.gps&w=80&h=92&yaw=188.40073&pitch=0&thumbfov=100'},
#  {'position': 11,
#   'title': 'beef steak spicy bolapelangi',
#   'place_id': 'ChIJL2aVRzuLcC4R6S8By3vLEaY',
#   'data_id': '0x2e708b3b4795662f:0xa611cb7bcb012fe9',
#   'data_cid': '11966569417447387113',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9809377999999995,
#    'longitude': 110.4244296},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b3b4795662f%3A0xa611cb7bcb012fe9%218m2%213d-6.9809377999999995%214d110.4244296&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': '2C9F+JQF, Gabahan, Semarang Tengah, Semarang City, Central Java 50135, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=A1zOu47mxt1eIuUUUf_Zrg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=19.593874&pitch=0&thumbfov=100'},
#  {'position': 12,
#   'title': 'Hans Steak',
#   'place_id': 'ChIJKwIlMECLcC4R6I8KGGzSs8w',
#   'data_id': '0x2e708b403025022b:0xccb3d26c180a8fe8',
#   'data_cid': '14750364566270152680',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9958234, 'longitude': 110.404715},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b403025022b%3A0xccb3d26c180a8fe8%218m2%213d-6.9958234%214d110.404715&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.8,
#   'reviews': 10,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C33+MVG, Jalan Kaligarang Raya, Barusari, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50244, Indonesia',
#   'open_state': 'Open ⋅ Closes 11PM',
#   'hours': 'Open ⋅ Closes 11PM',
#   'operating_hours': {'tuesday': '12–11PM',
#    'wednesday': '12–11PM',
#    'thursday': '12–11PM',
#    'friday': '12–11PM',
#    'saturday': '12–11PM',
#    'sunday': '12–11PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPm0c2HrgmNhi4-EjJIYQB2RgisVEa0V9XYXyEA=w99-h92-k-no'},
#  {'position': 13,
#   'title': 'jjsteak_therealsteak',
#   'place_id': 'ChIJpcSY1MmNcC4RqRhOAODVGpA',
#   'data_id': '0x2e708dc9d498c4a5:0x901ad5e0004e18a9',
#   'data_cid': '10383847048910608553',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9973417, 'longitude': 110.45581039999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9%218m2%213d-6.9973417%214d110.45581039999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 55,
#   'type': 'Steak house',
#   'address': 'Jl. Supriyadi No.20a, Kalicari, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50198, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–10PM',
#    'sunday': '11AM–10PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMSZ-QYnnSQC0scxmtfSHeMYXzvVaZMfMjU079o=w80-h106-k-no'},
#  {'position': 14,
#   'title': 'Royal Steak Citraland Mall',
#   'place_id': 'ChIJt_wE5ViLcC4RjATI-B32Jyo',
#   'data_id': '0x2e708b58e504fcb7:0x2a27f61df8c8048c',
#   'data_cid': '3037667082273031308',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.988728, 'longitude': 110.42369599999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b58e504fcb7%3A0x2a27f61df8c8048c%218m2%213d-6.988728%214d110.42369599999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.9,
#   'reviews': 13,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Mal Ciputra, Jalan simpang lima nomor 1, Citraland mall lantai 2, Food fair counter 11, Pekunden, Kec. Semarang Tengah, Kota Semarang, Jawa Tengah 50134, Indonesia',
#   'open_state': 'Open ⋅ Closes 9:30PM',
#   'hours': 'Open ⋅ Closes 9:30PM',
#   'operating_hours': {'tuesday': '9:30AM–9:30PM',
#    'wednesday': '9:30AM–9:30PM',
#    'thursday': '9:30AM–9:30PM',
#    'friday': '9:30AM–9:30PM',
#    'saturday': '9:30AM–9:30PM',
#    'sunday': '9:30AM–9:30PM',
#    'monday': '9:30AM–9:30PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPB23lKZAwvxQCERaBpIuz6rg-bNEMap3zWF1hm=w122-h92-k-no'},
#  {'position': 15,
#   'title': 'KhoKhu STEAK',
#   'place_id': 'ChIJ7WCwtwCMcC4REPjCbTl0_EM',
#   'data_id': '0x2e708c00b7b060ed:0x43fc74396dc2f810',
#   'data_cid': '4898918284675708944',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0232432, 'longitude': 110.4644659},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c00b7b060ed%3A0x43fc74396dc2f810%218m2%213d-7.0232432%214d110.4644659&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 229,
#   'type': 'Steak house',
#   'address': 'Jl. Gemah Jaya I, Kedungmundu, Tembalang, Semarang City, Central Java 50273, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '8AM–9PM',
#    'wednesday': '8AM–9PM',
#    'thursday': '8AM–9PM',
#    'friday': '8AM–9PM',
#    'saturday': '8AM–9PM',
#    'sunday': '8AM–9PM',
#    'monday': '8AM–9PM'},
#   'phone': '+62 878-7878-6241',
#   'website': 'https://www.facebook.com/khokhusteak.10414',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOCNTiV5n_8Ijv_Wrtqd1y2h9Xf_iCYutRzi6c=w204-h92-k-no'},
#  {'position': 16,
#   'title': 'Omah Steak',
#   'place_id': 'ChIJJYEA34uMcC4RdP6Tzg9iJu4',
#   'data_id': '0x2e708c8bdf008125:0xee26620fce93fe74',
#   'data_cid': '17160511250171690612',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0251882, 'longitude': 110.4602877},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c8bdf008125%3A0xee26620fce93fe74%218m2%213d-7.0251882%214d110.4602877&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': 'Jl. Kedungmundu No.19F, Kedungmundu, Kec. Tembalang, Kota Semarang, Jawa Tengah 50276, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=bbUS742SFXF7cOV2EGSCoQ&cb_client=search.gws-prod.gps&w=80&h=92&yaw=174.13599&pitch=0&thumbfov=100'},
#  {'position': 17,
#   'title': 'Steaky Steak Gajah Raya',
#   'place_id': 'ChIJk2lVeTqNcC4RbMlmYH1BwT0',
#   'data_id': '0x2e708d3a79556993:0x3dc1417d6066c96c',
#   'data_cid': '4449909913562827116',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9884702, 'longitude': 110.44835099999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708d3a79556993%3A0x3dc1417d6066c96c%218m2%213d-6.9884702%214d110.44835099999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 22,
#   'type': 'Steak house',
#   'address': 'Jl. Gajah Raya No.26 A, Siwalan, Kec. Gayamsari, Kota Semarang, Jawa Tengah 50262, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '12–9PM',
#    'wednesday': '12–9PM',
#    'thursday': '12–9PM',
#    'friday': '12–9PM',
#    'saturday': '12–9PM',
#    'sunday': '12–9PM',
#    'monday': '12–9PM'},
#   'phone': '+62 813-1923-4527',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOIkKZJDSPvlcWivR3-17C5g3zLTmLNBLkey-ic=w80-h142-k-no'},
#  {'position': 18,
#   'title': 'Omah Steak Qu',
#   'place_id': 'ChIJafZKkqiLcC4RfPs6n-p2Hgo',
#   'data_id': '0x2e708ba8924af669:0xa1e76ea9f3afb7c',
#   'data_cid': '729150939746466684',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9817195, 'longitude': 110.395702},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba8924af669%3A0xa1e76ea9f3afb7c%218m2%213d-6.9817195%214d110.395702&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 298,
#   'type': 'Steak house',
#   'address': 'Jl. Jenderal Sudirman, RT.001/RW.003, Cabean, Semarang Barat, Semarang City, Central Java 50141, Indonesia',
#   'open_state': 'Open ⋅ Closes 8PM',
#   'hours': 'Open ⋅ Closes 8PM',
#   'operating_hours': {'tuesday': '11:30AM–8PM',
#    'wednesday': '11:30AM–8PM',
#    'thursday': '11:30AM–8PM',
#    'friday': '11:30AM–8PM',
#    'saturday': '11:30AM–8PM',
#    'sunday': 'Closed',
#    'monday': '11:30AM–8PM'},
#   'phone': '+62 895-3270-76017',
#   'website': 'https://omah-steak-qu.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True,
#    'curbside_pickup': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipODaJ7qKrkRQMMtO9N0Y0e06RxjglhYzAlnwWty=w181-h92-k-no'},
#  {'position': 19,
#   'title': 'STAR STEAK',
#   'place_id': 'ChIJDbUrhDyJcC4RRPeD1oXmJ7g',
#   'data_id': '0x2e70893c842bb50d:0xb827e685d683f744',
#   'data_cid': '13269828289574467396',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0701481, 'longitude': 110.4219492},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e70893c842bb50d%3A0xb827e685d683f744%218m2%213d-7.0701481%214d110.4219492&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 318,
#   'type': 'Restaurant',
#   'address': 'Jl. Jati Raya No.25, Pedalangan, Kec. Banyumanik, Kota Semarang, Jawa Tengah 50268, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 858-8031-8858',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMYzqzTp4ybC6UGEn60Wbulm978VIWKlIw50Rgx=w199-h92-k-no'},
#  {'position': 20,
#   'title': 'Super steak jangli',
#   'place_id': 'ChIJgy7B1e2LcC4RhVj37ck6yEo',
#   'data_id': '0x2e708bedd5c12e83:0x4ac83ac9edf75885',
#   'data_cid': '5388621593104046213',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0275238, 'longitude': 110.424275},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708bedd5c12e83%3A0x4ac83ac9edf75885%218m2%213d-7.0275238%214d110.424275&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Fast food restaurant',
#   'address': 'Jl. Kesatrian rt003 No.h15, RW.008, Jatingaleh, Kec. Candisari, Kota Semarang, Jawa Tengah, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Alyg8hChtfhw9ZG82vRj_A&cb_client=search.gws-prod.gps&w=80&h=92&yaw=314.3858&pitch=0&thumbfov=100'}]

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  reviews = results["reviews"][i]["snippet"]
  print(reviews)
# Out:
# 5.0
# Tasty!! Very recommended
# 5.0
# Ok
# 5.0
# Ok
# 5.0
# Ok
# 5.0
# Like
# 5.0
# good
# 5.0
# (Translated by Google) At first I was skeptical about the place. But it turns out that it feels like a WINNER. cheap price. The service is good. My son accidentally went into the hot pan. The owner also gives free milk. Thank you very much. Success and more and more in demand so steak. (Original) Awalnya ragu sama tempatnya. Tapi ternyata RASANYA JUARA BGT. harga murah. Pelayanannya bagus. Ank saya g sengaja ke pan panasnya. Pemiliknya lgsg ngasih susu gratis. Makasih byk ya. Sukses dan makin laris so steak.
# 3.0
# (Translated by Google) The taste is quite good and the price is quite affordable. (Original) Rasa cukup enak dan harga cukup terjangkau.
# 5.0
# (Translated by Google) The place is cool, suitable for hangout, lots of photo spots who like selfies, the menu tastes good, endess really, cheap price, taste of luxury ... really recommended place (Original) Tempatnya keren cocok untuk tempat nongkrong byk spot foto yg hobi selfi, menunya rasanya enak endess bgt pokoknya, harga murah rasa mewah..tempat recommended bgt dahh
# 5.0
# (Translated by Google) It's really right, there are lots of coffee choices and the fried rice is really good (Original) Pas Banget, pilihan kopinya banyak dan nasi gorengnya mantab banget

# %%
#Posisi5
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b6236f09de5:0x35ae8e44b1f7dd5b",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Eatmeat Steak House',
#   'place_id': 'ChIJWYj5T66McC4RHa11Eq-lbvA',
#   'data_id': '0x2e708cae4ff98859:0xf06ea5af1275ad1d',
#   'data_cid': '17324966987888438557',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.981696599999999,
#    'longitude': 110.43589949999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cae4ff98859%3A0xf06ea5af1275ad1d%218m2%213d-6.981696599999999%214d110.43589949999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 3,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C9P+89C, Jl. Rejosari VII, Rejosari, Semarang Timur, Semarang City, Central Java 50125, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=UeSCBzPwdAhGcVhkBOLUhg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=334.76016&pitch=0&thumbfov=100'},
#  {'position': 2,
#   'title': 'Steaky Steak Sriwijaya Semarang',
#   'place_id': 'ChIJzxVGooKLcC4RiTjb6yLY4hA',
#   'data_id': '0x2e708b82a24615cf:0x10e2d822ebdb3889',
#   'data_cid': '1216772493840955529',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.999720699999999,
#    'longitude': 110.42240489999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b82a24615cf%3A0x10e2d822ebdb3889%218m2%213d-6.999720699999999%214d110.42240489999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 84,
#   'type': 'Steak house',
#   'address': 'Jl. Sriwijaya No.16, Tegalsari, Kec. Candisari, Kota Semarang, Jawa Tengah 50614, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11:30AM–9PM',
#    'wednesday': '11:30AM–9PM',
#    'thursday': '11:30AM–9PM',
#    'friday': '11:30AM–9PM',
#    'saturday': '11:30AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11:30AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN-q1TtYM39l_8VnZ8yPjC0wkfL-Drzgbr8TDN1=w80-h141-k-no'},
#  {'position': 3,
#   'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'place_id': 'ChIJ_UbCzYOLcC4R_zy6lNDVVhU',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'data_cid': '1537651414618750207',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0185885, 'longitude': 110.41940249999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b83cdc246fd%3A0x1556d5d094ba3cff%218m2%213d-7.0185885%214d110.41940249999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 2731,
#   'price': '$$',
#   'type': 'Steak house',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Candisari, Semarang City, Central Java 50232, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–11PM',
#    'sunday': '11AM–10PM',
#    'monday': '11AM–10PM'},
#   'phone': '+62 895-3549-91000',
#   'website': 'https://holycowsteak.com/',
#   'description': 'Restoran yg khusus menyajikan steak. Tempat makan yg menyajikan aneka pilihan daging berkualitas untuk steak, menerima panggilan kermh.',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPqPu4bqhe7bEBipPvmc-2Yi3pWSiXw7nfe4gOe=w163-h92-k-no'},
#  {'position': 4,
#   'title': 'STEAK ON THE STREET',
#   'place_id': 'ChIJ3bcbz7CNcC4Rm3lhyM7tzU0',
#   'data_id': '0x2e708db0cf1bb7dd:0x4dcdedcec861799b',
#   'data_cid': '5606398583527012763',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0396816, 'longitude': 110.4933362},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b%218m2%213d-7.0396816%214d110.4933362&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 5,
#   'reviews': 3,
#   'type': 'Steak house',
#   'address': 'Jl. Pucang Gading Raya No.104, Pucanggading, Batursari, Kec. Mranggen, Kabupaten Demak, Jawa Tengah 59567, Indonesia',
#   'open_state': 'Opens soon ⋅ 1PM',
#   'hours': 'Opens soon ⋅ 1PM',
#   'operating_hours': {'tuesday': '1–9PM',
#    'wednesday': '1–9PM',
#    'thursday': '1–9PM',
#    'friday': '1–9PM',
#    'saturday': '1–9PM',
#    'sunday': '1–9PM',
#    'monday': '1–9PM'},
#   'service_options': {'dine_in': True,
#    'drive_through': True,
#    'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoBouqPTUZvcPWyRMDJ6iiMkumZwei1Sz9KKmR=w163-h92-k-no'},
#  {'position': 5,
#   'title': 'Taman Sari Grilled Steak',
#   'place_id': 'ChIJB2uu93-LcC4RHEItlgp_X78',
#   'data_id': '0x2e708b7ff7ae6b07:0xbf5f7f0a962d421c',
#   'data_cid': '13789880267477697052',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0158051, 'longitude': 110.4256154},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c%218m2%213d-7.0158051%214d110.4256154&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 44,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'XCMG+M6H, Jl. Sisingamangaraja, Wonotingal, Kec. Candisari, Kota Semarang, Jawa Tengah 50525, Indonesia',
#   'open_state': 'Closed ⋅ Opens 4:30PM',
#   'hours': 'Closed ⋅ Opens 4:30PM',
#   'operating_hours': {'tuesday': '4:30–10PM',
#    'wednesday': '4:30–10PM',
#    'thursday': '4:30–10PM',
#    'friday': '4:30–10PM',
#    'saturday': '4:30–10PM',
#    'sunday': '4:30–10PM',
#    'monday': '4:30–10PM'},
#   'phone': '+62 812-2880-0077',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMIBpI0E2BiBfiDjiV0wgfgbl-PrO_ZnHpWlyuD=w122-h92-k-no'},
#  {'position': 6,
#   'title': 'Ins Steak House',
#   'place_id': 'ChIJw30Hzn-McC4Rw6s_u3UE-q8',
#   'data_id': '0x2e708c7fce077dc3:0xaffa0475bb3fabc3',
#   'data_cid': '12680452604514249667',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0174904, 'longitude': 110.4274169},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3%218m2%213d-7.0174904%214d110.4274169&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 6,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Dr. Wahidin No.92, Karanganyar Gunung, Candisari, Semarang City, Central Java 50253, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11AM–9PM'},
#   'phone': '+62 24 8310732',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEa34w2Qslkr037xNsf0EN_nTSyKcy6VhPcFIs=w80-h142-k-no'},
#  {'position': 7,
#   'title': 'So STEAK KENDAL',
#   'place_id': 'ChIJUXBXDGRdcC4R9CYZ14nMBzw',
#   'data_id': '0x2e705d640c577051:0x3c07cc89d71926f4',
#   'data_cid': '4325650859503986420',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9267803, 'longitude': 110.2071981},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e705d640c577051%3A0x3c07cc89d71926f4%218m2%213d-6.9267803%214d110.2071981&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 142,
#   'type': 'Restaurant',
#   'address': 'Kersan, Kebondalem, Kec. Kendal, Kabupaten Kendal, Jawa Tengah 51318, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': 'Closed'},
#   'phone': '+62 813-2949-2745',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPTe_Z-l8NMLqs2MSEHqNmY3KNuoLLrgmKu_C2d=w92-h92-k-no'},
#  {'position': 8,
#   'title': 'Star Steak',
#   'place_id': 'ChIJ5Z3wNmKLcC4RW933sUSOrjU',
#   'data_id': '0x2e708b6236f09de5:0x35ae8e44b1f7dd5b',
#   'data_cid': '3868185555652566363',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.010968999999999, 'longitude': 110.396046},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b%218m2%213d-7.010968999999999%214d110.396046&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 660,
#   'type': 'Steak house',
#   'address': 'Jl. Lamongan Raya No.12, Bendan Ngisor, Gajahmungkur, Semarang City, Central Java 50321, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '10AM–10PM',
#    'wednesday': '10AM–10PM',
#    'thursday': '10AM–10PM',
#    'friday': '10AM–10PM',
#    'saturday': '10AM–10PM',
#    'sunday': '10AM–10PM',
#    'monday': '10AM–10PM'},
#   'phone': '+62 858-8031-8858',
#   'website': 'https://starsteak-steakhouse.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP53s4hhDWTGrSUpbs4z7h5UrHVYdg07T3NkS7K=w194-h92-k-no'},
#  {'position': 9,
#   'title': 'Chicken Steak Crispy',
#   'place_id': 'ChIJ63e8DKaLcC4RI1wT2vMWTQA',
#   'data_id': '0x2e708ba60cbc77eb:0x4d16f3da135c23',
#   'data_cid': '21698809798286371',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9959221, 'longitude': 110.42092559999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba60cbc77eb%3A0x4d16f3da135c23%218m2%213d-6.9959221%214d110.42092559999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 15,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Pleburan Barat No.42, Pleburan, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50241, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNud-mXw04ejp8ArcZJXB_RDM2QpW7QnSGFjroI=w80-h142-k-no'},
#  {'position': 10,
#   'title': "MR FAT'S CHEESE STEAK",
#   'place_id': 'ChIJYQlJbsaMcC4Rl8VTYaRKD1g',
#   'data_id': '0x2e708cc66e490961:0x580f4aa46153c597',
#   'data_cid': '6345372469856290199',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9857739, 'longitude': 110.45514759999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cc66e490961%3A0x580f4aa46153c597%218m2%213d-6.9857739%214d110.45514759999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 22,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jalan Soekarno Hatta No.12 (Omah Jones), Kel. Tlogosari kulon , Kec. Gayamsari, Tlogosari Kulon, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50166, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 812-2622-7972',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Dg3XR_w3rqfIAftwT24KiA&cb_client=search.gws-prod.gps&w=80&h=92&yaw=188.40073&pitch=0&thumbfov=100'},
#  {'position': 11,
#   'title': 'beef steak spicy bolapelangi',
#   'place_id': 'ChIJL2aVRzuLcC4R6S8By3vLEaY',
#   'data_id': '0x2e708b3b4795662f:0xa611cb7bcb012fe9',
#   'data_cid': '11966569417447387113',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9809377999999995,
#    'longitude': 110.4244296},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b3b4795662f%3A0xa611cb7bcb012fe9%218m2%213d-6.9809377999999995%214d110.4244296&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': '2C9F+JQF, Gabahan, Semarang Tengah, Semarang City, Central Java 50135, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=A1zOu47mxt1eIuUUUf_Zrg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=19.593874&pitch=0&thumbfov=100'},
#  {'position': 12,
#   'title': 'Hans Steak',
#   'place_id': 'ChIJKwIlMECLcC4R6I8KGGzSs8w',
#   'data_id': '0x2e708b403025022b:0xccb3d26c180a8fe8',
#   'data_cid': '14750364566270152680',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9958234, 'longitude': 110.404715},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b403025022b%3A0xccb3d26c180a8fe8%218m2%213d-6.9958234%214d110.404715&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.8,
#   'reviews': 10,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C33+MVG, Jalan Kaligarang Raya, Barusari, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50244, Indonesia',
#   'open_state': 'Open ⋅ Closes 11PM',
#   'hours': 'Open ⋅ Closes 11PM',
#   'operating_hours': {'tuesday': '12–11PM',
#    'wednesday': '12–11PM',
#    'thursday': '12–11PM',
#    'friday': '12–11PM',
#    'saturday': '12–11PM',
#    'sunday': '12–11PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPm0c2HrgmNhi4-EjJIYQB2RgisVEa0V9XYXyEA=w99-h92-k-no'},
#  {'position': 13,
#   'title': 'jjsteak_therealsteak',
#   'place_id': 'ChIJpcSY1MmNcC4RqRhOAODVGpA',
#   'data_id': '0x2e708dc9d498c4a5:0x901ad5e0004e18a9',
#   'data_cid': '10383847048910608553',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9973417, 'longitude': 110.45581039999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9%218m2%213d-6.9973417%214d110.45581039999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 55,
#   'type': 'Steak house',
#   'address': 'Jl. Supriyadi No.20a, Kalicari, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50198, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–10PM',
#    'sunday': '11AM–10PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMSZ-QYnnSQC0scxmtfSHeMYXzvVaZMfMjU079o=w80-h106-k-no'},
#  {'position': 14,
#   'title': 'Royal Steak Citraland Mall',
#   'place_id': 'ChIJt_wE5ViLcC4RjATI-B32Jyo',
#   'data_id': '0x2e708b58e504fcb7:0x2a27f61df8c8048c',
#   'data_cid': '3037667082273031308',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.988728, 'longitude': 110.42369599999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b58e504fcb7%3A0x2a27f61df8c8048c%218m2%213d-6.988728%214d110.42369599999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.9,
#   'reviews': 13,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Mal Ciputra, Jalan simpang lima nomor 1, Citraland mall lantai 2, Food fair counter 11, Pekunden, Kec. Semarang Tengah, Kota Semarang, Jawa Tengah 50134, Indonesia',
#   'open_state': 'Open ⋅ Closes 9:30PM',
#   'hours': 'Open ⋅ Closes 9:30PM',
#   'operating_hours': {'tuesday': '9:30AM–9:30PM',
#    'wednesday': '9:30AM–9:30PM',
#    'thursday': '9:30AM–9:30PM',
#    'friday': '9:30AM–9:30PM',
#    'saturday': '9:30AM–9:30PM',
#    'sunday': '9:30AM–9:30PM',
#    'monday': '9:30AM–9:30PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPB23lKZAwvxQCERaBpIuz6rg-bNEMap3zWF1hm=w122-h92-k-no'},
#  {'position': 15,
#   'title': 'KhoKhu STEAK',
#   'place_id': 'ChIJ7WCwtwCMcC4REPjCbTl0_EM',
#   'data_id': '0x2e708c00b7b060ed:0x43fc74396dc2f810',
#   'data_cid': '4898918284675708944',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0232432, 'longitude': 110.4644659},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c00b7b060ed%3A0x43fc74396dc2f810%218m2%213d-7.0232432%214d110.4644659&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 229,
#   'type': 'Steak house',
#   'address': 'Jl. Gemah Jaya I, Kedungmundu, Tembalang, Semarang City, Central Java 50273, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '8AM–9PM',
#    'wednesday': '8AM–9PM',
#    'thursday': '8AM–9PM',
#    'friday': '8AM–9PM',
#    'saturday': '8AM–9PM',
#    'sunday': '8AM–9PM',
#    'monday': '8AM–9PM'},
#   'phone': '+62 878-7878-6241',
#   'website': 'https://www.facebook.com/khokhusteak.10414',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOCNTiV5n_8Ijv_Wrtqd1y2h9Xf_iCYutRzi6c=w204-h92-k-no'},
#  {'position': 16,
#   'title': 'Omah Steak',
#   'place_id': 'ChIJJYEA34uMcC4RdP6Tzg9iJu4',
#   'data_id': '0x2e708c8bdf008125:0xee26620fce93fe74',
#   'data_cid': '17160511250171690612',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0251882, 'longitude': 110.4602877},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c8bdf008125%3A0xee26620fce93fe74%218m2%213d-7.0251882%214d110.4602877&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': 'Jl. Kedungmundu No.19F, Kedungmundu, Kec. Tembalang, Kota Semarang, Jawa Tengah 50276, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=bbUS742SFXF7cOV2EGSCoQ&cb_client=search.gws-prod.gps&w=80&h=92&yaw=174.13599&pitch=0&thumbfov=100'},
#  {'position': 17,
#   'title': 'Steaky Steak Gajah Raya',
#   'place_id': 'ChIJk2lVeTqNcC4RbMlmYH1BwT0',
#   'data_id': '0x2e708d3a79556993:0x3dc1417d6066c96c',
#   'data_cid': '4449909913562827116',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9884702, 'longitude': 110.44835099999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708d3a79556993%3A0x3dc1417d6066c96c%218m2%213d-6.9884702%214d110.44835099999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 22,
#   'type': 'Steak house',
#   'address': 'Jl. Gajah Raya No.26 A, Siwalan, Kec. Gayamsari, Kota Semarang, Jawa Tengah 50262, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '12–9PM',
#    'wednesday': '12–9PM',
#    'thursday': '12–9PM',
#    'friday': '12–9PM',
#    'saturday': '12–9PM',
#    'sunday': '12–9PM',
#    'monday': '12–9PM'},
#   'phone': '+62 813-1923-4527',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOIkKZJDSPvlcWivR3-17C5g3zLTmLNBLkey-ic=w80-h142-k-no'},
#  {'position': 18,
#   'title': 'Omah Steak Qu',
#   'place_id': 'ChIJafZKkqiLcC4RfPs6n-p2Hgo',
#   'data_id': '0x2e708ba8924af669:0xa1e76ea9f3afb7c',
#   'data_cid': '729150939746466684',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9817195, 'longitude': 110.395702},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba8924af669%3A0xa1e76ea9f3afb7c%218m2%213d-6.9817195%214d110.395702&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 298,
#   'type': 'Steak house',
#   'address': 'Jl. Jenderal Sudirman, RT.001/RW.003, Cabean, Semarang Barat, Semarang City, Central Java 50141, Indonesia',
#   'open_state': 'Open ⋅ Closes 8PM',
#   'hours': 'Open ⋅ Closes 8PM',
#   'operating_hours': {'tuesday': '11:30AM–8PM',
#    'wednesday': '11:30AM–8PM',
#    'thursday': '11:30AM–8PM',
#    'friday': '11:30AM–8PM',
#    'saturday': '11:30AM–8PM',
#    'sunday': 'Closed',
#    'monday': '11:30AM–8PM'},
#   'phone': '+62 895-3270-76017',
#   'website': 'https://omah-steak-qu.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True,
#    'curbside_pickup': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipODaJ7qKrkRQMMtO9N0Y0e06RxjglhYzAlnwWty=w181-h92-k-no'},
#  {'position': 19,
#   'title': 'STAR STEAK',
#   'place_id': 'ChIJDbUrhDyJcC4RRPeD1oXmJ7g',
#   'data_id': '0x2e70893c842bb50d:0xb827e685d683f744',
#   'data_cid': '13269828289574467396',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0701481, 'longitude': 110.4219492},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e70893c842bb50d%3A0xb827e685d683f744%218m2%213d-7.0701481%214d110.4219492&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 318,
#   'type': 'Restaurant',
#   'address': 'Jl. Jati Raya No.25, Pedalangan, Kec. Banyumanik, Kota Semarang, Jawa Tengah 50268, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 858-8031-8858',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMYzqzTp4ybC6UGEn60Wbulm978VIWKlIw50Rgx=w199-h92-k-no'},
#  {'position': 20,
#   'title': 'Super steak jangli',
#   'place_id': 'ChIJgy7B1e2LcC4RhVj37ck6yEo',
#   'data_id': '0x2e708bedd5c12e83:0x4ac83ac9edf75885',
#   'data_cid': '5388621593104046213',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0275238, 'longitude': 110.424275},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708bedd5c12e83%3A0x4ac83ac9edf75885%218m2%213d-7.0275238%214d110.424275&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Fast food restaurant',
#   'address': 'Jl. Kesatrian rt003 No.h15, RW.008, Jatingaleh, Kec. Candisari, Kota Semarang, Jawa Tengah, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Alyg8hChtfhw9ZG82vRj_A&cb_client=search.gws-prod.gps&w=80&h=92&yaw=314.3858&pitch=0&thumbfov=100'}]

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  reviews = results["reviews"][i]["snippet"]
  print(reviews)
# Out:
# 5.0
# Foods in here are very delicious, also the main dish. The waiters are friendly and polite.
# 5.0
# Good taste, good service, good place. Sukses terus stat steak
# 3.0
# The steak is thin. maybe because the price..
# 4.0
# The taste is good
# 3.0
# a place to eat steak that is cheap, the taste does not disappoint, the portion is sufficient and the atmosphere is quite clean.
# 5.0
# Affordable price, cheaper than Waroeng steak. Sorry, i forgot to take the pict.
# 3.0
# Bad service, we have booked place and ordered the food, but it still took so long
# 4.0
# simple price but not bad......
# 5.0
# Reasonable price and tasty...
# 3.0
# OK for meals. Not OK for light

# %%
#Posisi6
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708ba60cbc77eb:0x4d16f3da135c23",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Eatmeat Steak House',
#   'place_id': 'ChIJWYj5T66McC4RHa11Eq-lbvA',
#   'data_id': '0x2e708cae4ff98859:0xf06ea5af1275ad1d',
#   'data_cid': '17324966987888438557',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.981696599999999,
#    'longitude': 110.43589949999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cae4ff98859%3A0xf06ea5af1275ad1d%218m2%213d-6.981696599999999%214d110.43589949999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 3,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C9P+89C, Jl. Rejosari VII, Rejosari, Semarang Timur, Semarang City, Central Java 50125, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=UeSCBzPwdAhGcVhkBOLUhg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=334.76016&pitch=0&thumbfov=100'},
#  {'position': 2,
#   'title': 'Steaky Steak Sriwijaya Semarang',
#   'place_id': 'ChIJzxVGooKLcC4RiTjb6yLY4hA',
#   'data_id': '0x2e708b82a24615cf:0x10e2d822ebdb3889',
#   'data_cid': '1216772493840955529',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.999720699999999,
#    'longitude': 110.42240489999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b82a24615cf%3A0x10e2d822ebdb3889%218m2%213d-6.999720699999999%214d110.42240489999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 84,
#   'type': 'Steak house',
#   'address': 'Jl. Sriwijaya No.16, Tegalsari, Kec. Candisari, Kota Semarang, Jawa Tengah 50614, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11:30AM–9PM',
#    'wednesday': '11:30AM–9PM',
#    'thursday': '11:30AM–9PM',
#    'friday': '11:30AM–9PM',
#    'saturday': '11:30AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11:30AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN-q1TtYM39l_8VnZ8yPjC0wkfL-Drzgbr8TDN1=w80-h141-k-no'},
#  {'position': 3,
#   'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'place_id': 'ChIJ_UbCzYOLcC4R_zy6lNDVVhU',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'data_cid': '1537651414618750207',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0185885, 'longitude': 110.41940249999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b83cdc246fd%3A0x1556d5d094ba3cff%218m2%213d-7.0185885%214d110.41940249999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 2731,
#   'price': '$$',
#   'type': 'Steak house',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Candisari, Semarang City, Central Java 50232, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–11PM',
#    'sunday': '11AM–10PM',
#    'monday': '11AM–10PM'},
#   'phone': '+62 895-3549-91000',
#   'website': 'https://holycowsteak.com/',
#   'description': 'Restoran yg khusus menyajikan steak. Tempat makan yg menyajikan aneka pilihan daging berkualitas untuk steak, menerima panggilan kermh.',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPqPu4bqhe7bEBipPvmc-2Yi3pWSiXw7nfe4gOe=w163-h92-k-no'},
#  {'position': 4,
#   'title': 'STEAK ON THE STREET',
#   'place_id': 'ChIJ3bcbz7CNcC4Rm3lhyM7tzU0',
#   'data_id': '0x2e708db0cf1bb7dd:0x4dcdedcec861799b',
#   'data_cid': '5606398583527012763',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0396816, 'longitude': 110.4933362},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b%218m2%213d-7.0396816%214d110.4933362&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 5,
#   'reviews': 3,
#   'type': 'Steak house',
#   'address': 'Jl. Pucang Gading Raya No.104, Pucanggading, Batursari, Kec. Mranggen, Kabupaten Demak, Jawa Tengah 59567, Indonesia',
#   'open_state': 'Opens soon ⋅ 1PM',
#   'hours': 'Opens soon ⋅ 1PM',
#   'operating_hours': {'tuesday': '1–9PM',
#    'wednesday': '1–9PM',
#    'thursday': '1–9PM',
#    'friday': '1–9PM',
#    'saturday': '1–9PM',
#    'sunday': '1–9PM',
#    'monday': '1–9PM'},
#   'service_options': {'dine_in': True,
#    'drive_through': True,
#    'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoBouqPTUZvcPWyRMDJ6iiMkumZwei1Sz9KKmR=w163-h92-k-no'},
#  {'position': 5,
#   'title': 'Taman Sari Grilled Steak',
#   'place_id': 'ChIJB2uu93-LcC4RHEItlgp_X78',
#   'data_id': '0x2e708b7ff7ae6b07:0xbf5f7f0a962d421c',
#   'data_cid': '13789880267477697052',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0158051, 'longitude': 110.4256154},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c%218m2%213d-7.0158051%214d110.4256154&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 44,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'XCMG+M6H, Jl. Sisingamangaraja, Wonotingal, Kec. Candisari, Kota Semarang, Jawa Tengah 50525, Indonesia',
#   'open_state': 'Closed ⋅ Opens 4:30PM',
#   'hours': 'Closed ⋅ Opens 4:30PM',
#   'operating_hours': {'tuesday': '4:30–10PM',
#    'wednesday': '4:30–10PM',
#    'thursday': '4:30–10PM',
#    'friday': '4:30–10PM',
#    'saturday': '4:30–10PM',
#    'sunday': '4:30–10PM',
#    'monday': '4:30–10PM'},
#   'phone': '+62 812-2880-0077',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMIBpI0E2BiBfiDjiV0wgfgbl-PrO_ZnHpWlyuD=w122-h92-k-no'},
#  {'position': 6,
#   'title': 'Ins Steak House',
#   'place_id': 'ChIJw30Hzn-McC4Rw6s_u3UE-q8',
#   'data_id': '0x2e708c7fce077dc3:0xaffa0475bb3fabc3',
#   'data_cid': '12680452604514249667',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0174904, 'longitude': 110.4274169},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3%218m2%213d-7.0174904%214d110.4274169&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 6,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Dr. Wahidin No.92, Karanganyar Gunung, Candisari, Semarang City, Central Java 50253, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11AM–9PM'},
#   'phone': '+62 24 8310732',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEa34w2Qslkr037xNsf0EN_nTSyKcy6VhPcFIs=w80-h142-k-no'},
#  {'position': 7,
#   'title': 'So STEAK KENDAL',
#   'place_id': 'ChIJUXBXDGRdcC4R9CYZ14nMBzw',
#   'data_id': '0x2e705d640c577051:0x3c07cc89d71926f4',
#   'data_cid': '4325650859503986420',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9267803, 'longitude': 110.2071981},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e705d640c577051%3A0x3c07cc89d71926f4%218m2%213d-6.9267803%214d110.2071981&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 142,
#   'type': 'Restaurant',
#   'address': 'Kersan, Kebondalem, Kec. Kendal, Kabupaten Kendal, Jawa Tengah 51318, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': 'Closed'},
#   'phone': '+62 813-2949-2745',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPTe_Z-l8NMLqs2MSEHqNmY3KNuoLLrgmKu_C2d=w92-h92-k-no'},
#  {'position': 8,
#   'title': 'Star Steak',
#   'place_id': 'ChIJ5Z3wNmKLcC4RW933sUSOrjU',
#   'data_id': '0x2e708b6236f09de5:0x35ae8e44b1f7dd5b',
#   'data_cid': '3868185555652566363',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.010968999999999, 'longitude': 110.396046},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b%218m2%213d-7.010968999999999%214d110.396046&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 660,
#   'type': 'Steak house',
#   'address': 'Jl. Lamongan Raya No.12, Bendan Ngisor, Gajahmungkur, Semarang City, Central Java 50321, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '10AM–10PM',
#    'wednesday': '10AM–10PM',
#    'thursday': '10AM–10PM',
#    'friday': '10AM–10PM',
#    'saturday': '10AM–10PM',
#    'sunday': '10AM–10PM',
#    'monday': '10AM–10PM'},
#   'phone': '+62 858-8031-8858',
#   'website': 'https://starsteak-steakhouse.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP53s4hhDWTGrSUpbs4z7h5UrHVYdg07T3NkS7K=w194-h92-k-no'},
#  {'position': 9,
#   'title': 'Chicken Steak Crispy',
#   'place_id': 'ChIJ63e8DKaLcC4RI1wT2vMWTQA',
#   'data_id': '0x2e708ba60cbc77eb:0x4d16f3da135c23',
#   'data_cid': '21698809798286371',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9959221, 'longitude': 110.42092559999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba60cbc77eb%3A0x4d16f3da135c23%218m2%213d-6.9959221%214d110.42092559999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 15,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Pleburan Barat No.42, Pleburan, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50241, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNud-mXw04ejp8ArcZJXB_RDM2QpW7QnSGFjroI=w80-h142-k-no'},
#  {'position': 10,
#   'title': "MR FAT'S CHEESE STEAK",
#   'place_id': 'ChIJYQlJbsaMcC4Rl8VTYaRKD1g',
#   'data_id': '0x2e708cc66e490961:0x580f4aa46153c597',
#   'data_cid': '6345372469856290199',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9857739, 'longitude': 110.45514759999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cc66e490961%3A0x580f4aa46153c597%218m2%213d-6.9857739%214d110.45514759999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 22,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jalan Soekarno Hatta No.12 (Omah Jones), Kel. Tlogosari kulon , Kec. Gayamsari, Tlogosari Kulon, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50166, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 812-2622-7972',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Dg3XR_w3rqfIAftwT24KiA&cb_client=search.gws-prod.gps&w=80&h=92&yaw=188.40073&pitch=0&thumbfov=100'},
#  {'position': 11,
#   'title': 'beef steak spicy bolapelangi',
#   'place_id': 'ChIJL2aVRzuLcC4R6S8By3vLEaY',
#   'data_id': '0x2e708b3b4795662f:0xa611cb7bcb012fe9',
#   'data_cid': '11966569417447387113',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9809377999999995,
#    'longitude': 110.4244296},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b3b4795662f%3A0xa611cb7bcb012fe9%218m2%213d-6.9809377999999995%214d110.4244296&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': '2C9F+JQF, Gabahan, Semarang Tengah, Semarang City, Central Java 50135, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=A1zOu47mxt1eIuUUUf_Zrg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=19.593874&pitch=0&thumbfov=100'},
#  {'position': 12,
#   'title': 'Hans Steak',
#   'place_id': 'ChIJKwIlMECLcC4R6I8KGGzSs8w',
#   'data_id': '0x2e708b403025022b:0xccb3d26c180a8fe8',
#   'data_cid': '14750364566270152680',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9958234, 'longitude': 110.404715},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b403025022b%3A0xccb3d26c180a8fe8%218m2%213d-6.9958234%214d110.404715&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.8,
#   'reviews': 10,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C33+MVG, Jalan Kaligarang Raya, Barusari, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50244, Indonesia',
#   'open_state': 'Open ⋅ Closes 11PM',
#   'hours': 'Open ⋅ Closes 11PM',
#   'operating_hours': {'tuesday': '12–11PM',
#    'wednesday': '12–11PM',
#    'thursday': '12–11PM',
#    'friday': '12–11PM',
#    'saturday': '12–11PM',
#    'sunday': '12–11PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPm0c2HrgmNhi4-EjJIYQB2RgisVEa0V9XYXyEA=w99-h92-k-no'},
#  {'position': 13,
#   'title': 'jjsteak_therealsteak',
#   'place_id': 'ChIJpcSY1MmNcC4RqRhOAODVGpA',
#   'data_id': '0x2e708dc9d498c4a5:0x901ad5e0004e18a9',
#   'data_cid': '10383847048910608553',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9973417, 'longitude': 110.45581039999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9%218m2%213d-6.9973417%214d110.45581039999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 55,
#   'type': 'Steak house',
#   'address': 'Jl. Supriyadi No.20a, Kalicari, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50198, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–10PM',
#    'sunday': '11AM–10PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMSZ-QYnnSQC0scxmtfSHeMYXzvVaZMfMjU079o=w80-h106-k-no'},
#  {'position': 14,
#   'title': 'Royal Steak Citraland Mall',
#   'place_id': 'ChIJt_wE5ViLcC4RjATI-B32Jyo',
#   'data_id': '0x2e708b58e504fcb7:0x2a27f61df8c8048c',
#   'data_cid': '3037667082273031308',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.988728, 'longitude': 110.42369599999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b58e504fcb7%3A0x2a27f61df8c8048c%218m2%213d-6.988728%214d110.42369599999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.9,
#   'reviews': 13,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Mal Ciputra, Jalan simpang lima nomor 1, Citraland mall lantai 2, Food fair counter 11, Pekunden, Kec. Semarang Tengah, Kota Semarang, Jawa Tengah 50134, Indonesia',
#   'open_state': 'Open ⋅ Closes 9:30PM',
#   'hours': 'Open ⋅ Closes 9:30PM',
#   'operating_hours': {'tuesday': '9:30AM–9:30PM',
#    'wednesday': '9:30AM–9:30PM',
#    'thursday': '9:30AM–9:30PM',
#    'friday': '9:30AM–9:30PM',
#    'saturday': '9:30AM–9:30PM',
#    'sunday': '9:30AM–9:30PM',
#    'monday': '9:30AM–9:30PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPB23lKZAwvxQCERaBpIuz6rg-bNEMap3zWF1hm=w122-h92-k-no'},
#  {'position': 15,
#   'title': 'KhoKhu STEAK',
#   'place_id': 'ChIJ7WCwtwCMcC4REPjCbTl0_EM',
#   'data_id': '0x2e708c00b7b060ed:0x43fc74396dc2f810',
#   'data_cid': '4898918284675708944',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0232432, 'longitude': 110.4644659},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c00b7b060ed%3A0x43fc74396dc2f810%218m2%213d-7.0232432%214d110.4644659&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 229,
#   'type': 'Steak house',
#   'address': 'Jl. Gemah Jaya I, Kedungmundu, Tembalang, Semarang City, Central Java 50273, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '8AM–9PM',
#    'wednesday': '8AM–9PM',
#    'thursday': '8AM–9PM',
#    'friday': '8AM–9PM',
#    'saturday': '8AM–9PM',
#    'sunday': '8AM–9PM',
#    'monday': '8AM–9PM'},
#   'phone': '+62 878-7878-6241',
#   'website': 'https://www.facebook.com/khokhusteak.10414',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOCNTiV5n_8Ijv_Wrtqd1y2h9Xf_iCYutRzi6c=w204-h92-k-no'},
#  {'position': 16,
#   'title': 'Omah Steak',
#   'place_id': 'ChIJJYEA34uMcC4RdP6Tzg9iJu4',
#   'data_id': '0x2e708c8bdf008125:0xee26620fce93fe74',
#   'data_cid': '17160511250171690612',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0251882, 'longitude': 110.4602877},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c8bdf008125%3A0xee26620fce93fe74%218m2%213d-7.0251882%214d110.4602877&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': 'Jl. Kedungmundu No.19F, Kedungmundu, Kec. Tembalang, Kota Semarang, Jawa Tengah 50276, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=bbUS742SFXF7cOV2EGSCoQ&cb_client=search.gws-prod.gps&w=80&h=92&yaw=174.13599&pitch=0&thumbfov=100'},
#  {'position': 17,
#   'title': 'Steaky Steak Gajah Raya',
#   'place_id': 'ChIJk2lVeTqNcC4RbMlmYH1BwT0',
#   'data_id': '0x2e708d3a79556993:0x3dc1417d6066c96c',
#   'data_cid': '4449909913562827116',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9884702, 'longitude': 110.44835099999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708d3a79556993%3A0x3dc1417d6066c96c%218m2%213d-6.9884702%214d110.44835099999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 22,
#   'type': 'Steak house',
#   'address': 'Jl. Gajah Raya No.26 A, Siwalan, Kec. Gayamsari, Kota Semarang, Jawa Tengah 50262, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '12–9PM',
#    'wednesday': '12–9PM',
#    'thursday': '12–9PM',
#    'friday': '12–9PM',
#    'saturday': '12–9PM',
#    'sunday': '12–9PM',
#    'monday': '12–9PM'},
#   'phone': '+62 813-1923-4527',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOIkKZJDSPvlcWivR3-17C5g3zLTmLNBLkey-ic=w80-h142-k-no'},
#  {'position': 18,
#   'title': 'Omah Steak Qu',
#   'place_id': 'ChIJafZKkqiLcC4RfPs6n-p2Hgo',
#   'data_id': '0x2e708ba8924af669:0xa1e76ea9f3afb7c',
#   'data_cid': '729150939746466684',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9817195, 'longitude': 110.395702},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba8924af669%3A0xa1e76ea9f3afb7c%218m2%213d-6.9817195%214d110.395702&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 298,
#   'type': 'Steak house',
#   'address': 'Jl. Jenderal Sudirman, RT.001/RW.003, Cabean, Semarang Barat, Semarang City, Central Java 50141, Indonesia',
#   'open_state': 'Open ⋅ Closes 8PM',
#   'hours': 'Open ⋅ Closes 8PM',
#   'operating_hours': {'tuesday': '11:30AM–8PM',
#    'wednesday': '11:30AM–8PM',
#    'thursday': '11:30AM–8PM',
#    'friday': '11:30AM–8PM',
#    'saturday': '11:30AM–8PM',
#    'sunday': 'Closed',
#    'monday': '11:30AM–8PM'},
#   'phone': '+62 895-3270-76017',
#   'website': 'https://omah-steak-qu.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True,
#    'curbside_pickup': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipODaJ7qKrkRQMMtO9N0Y0e06RxjglhYzAlnwWty=w181-h92-k-no'},
#  {'position': 19,
#   'title': 'STAR STEAK',
#   'place_id': 'ChIJDbUrhDyJcC4RRPeD1oXmJ7g',
#   'data_id': '0x2e70893c842bb50d:0xb827e685d683f744',
#   'data_cid': '13269828289574467396',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0701481, 'longitude': 110.4219492},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e70893c842bb50d%3A0xb827e685d683f744%218m2%213d-7.0701481%214d110.4219492&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 318,
#   'type': 'Restaurant',
#   'address': 'Jl. Jati Raya No.25, Pedalangan, Kec. Banyumanik, Kota Semarang, Jawa Tengah 50268, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 858-8031-8858',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMYzqzTp4ybC6UGEn60Wbulm978VIWKlIw50Rgx=w199-h92-k-no'},
#  {'position': 20,
#   'title': 'Super steak jangli',
#   'place_id': 'ChIJgy7B1e2LcC4RhVj37ck6yEo',
#   'data_id': '0x2e708bedd5c12e83:0x4ac83ac9edf75885',
#   'data_cid': '5388621593104046213',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0275238, 'longitude': 110.424275},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708bedd5c12e83%3A0x4ac83ac9edf75885%218m2%213d-7.0275238%214d110.424275&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Fast food restaurant',
#   'address': 'Jl. Kesatrian rt003 No.h15, RW.008, Jatingaleh, Kec. Candisari, Kota Semarang, Jawa Tengah, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Alyg8hChtfhw9ZG82vRj_A&cb_client=search.gws-prod.gps&w=80&h=92&yaw=314.3858&pitch=0&thumbfov=100'}]

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  reviews = results["reviews"][i]["snippet"]
  print(reviews)
# Out:
# 5.0
# (Translated by Google) Good food, clean place, good service, friendly prices (Original) Makanan enak , tempat bersih, pelayanan baik, harga bersahabat
# 1.0
# (Translated by Google) Buy c(Original)Beli c
# 4.0
# (Translated by Google) Delicious, friendly service and affordable prices (Original) Enak, pelayanan ramah dan harga terjangkau
# 3.0
# (Translated by Google) same as other steak steaks.(Original)sama kyk steak steak lainnya.
# 5.0
# (Translated by Google) Yummy(Original)Nyummy
# 5.0
# (Translated by Google) If(Original)Jos
# 5.0
#
# 5.0
#
# 4.0
#
# 5.0

# %%
#Posisi7
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e
# (Translated by Google) A very pocket-friendly steak place, with a steak for 60 thousand you've got meat that tastes delicious, the location is in the food court, parking is wide but not in front of other stalls wkwkwk, the meat is thick, fresh, the sauce is delicious, the side dishes are also delicious, only the french fries are a bit hard, There is also ice cream for dessert and various drinks Come before dinner time because there will be a waiting list hehe, come directly choose a table / write the waiting list order in front of the shop, then write the menu, wait for the waiter to call you when there is an empty table that has been cleaned Recommended (Original) Tempat makan steak yang sangat ramah di kantong, dengan steak seharga 60rb an sudah mendapat daging yang rasanya maknyusss, lokasinya di dalam foodcourt, parkir luas tp jangan di depan warung lain wkwk, dagingnya tebal, segar, saos enak, side dish juga enak, cuman french fries nya agak keras, Ada eskrim juga untuk pencuci mulut dan berbagai minuman Datang lah sebelum jam makan malam karna bakal waiting list hehe, datang langsung pilih meja/nulis urutan waiting list di depan warung nya, trus nulis menu, nanti tunggu dipanggil dari pelayannya kalau sudah ada meja kosong yg sudah dibersihkan Recommended
# 5.0
# (Translated by Google) The meat is juicy.. according to the order medium well.. The salad is also delicious.. reasonable price The portion of the cocktail sauce is just right. The stand is at the far left of the entrance. The last time I was there, luckily there was no waiting list, I immediately got a table.. The bbq sauce was delicious, the mushroom sauce wasn't very tasty.. (Original) Daging nya juicy.. sesuai pesanan medium well.. Salad ny juga enak.. reasonable price Sausage cocktail porsinya pas banget. Stand ada di paling ujung kiri dari pintu masuk. Terakhir kesana untung nya tidak waiting list, langsung dapat meja..saus bbq nya enak, saus jamur nya kurang kerasa..

# %%
#Posisi9
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708c00b7b060ed:0x43fc74396dc2f810",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Eatmeat Steak House',
#   'place_id': 'ChIJWYj5T66McC4RHa11Eq-lbvA',
#   'data_id': '0x2e708cae4ff98859:0xf06ea5af1275ad1d',
#   'data_cid': '17324966987888438557',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.981696599999999,
#    'longitude': 110.43589949999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cae4ff98859%3A0xf06ea5af1275ad1d%218m2%213d-6.981696599999999%214d110.43589949999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 3,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C9P+89C, Jl. Rejosari VII, Rejosari, Semarang Timur, Semarang City, Central Java 50125, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=UeSCBzPwdAhGcVhkBOLUhg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=334.76016&pitch=0&thumbfov=100'},
#  {'position': 2,
#   'title': 'Steaky Steak Sriwijaya Semarang',
#   'place_id': 'ChIJzxVGooKLcC4RiTjb6yLY4hA',
#   'data_id': '0x2e708b82a24615cf:0x10e2d822ebdb3889',
#   'data_cid': '1216772493840955529',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.999720699999999,
#    'longitude': 110.42240489999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b82a24615cf%3A0x10e2d822ebdb3889%218m2%213d-6.999720699999999%214d110.42240489999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 84,
#   'type': 'Steak house',
#   'address': 'Jl. Sriwijaya No.16, Tegalsari, Kec. Candisari, Kota Semarang, Jawa Tengah 50614, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11:30AM–9PM',
#    'wednesday': '11:30AM–9PM',
#    'thursday': '11:30AM–9PM',
#    'friday': '11:30AM–9PM',
#    'saturday': '11:30AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11:30AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN-q1TtYM39l_8VnZ8yPjC0wkfL-Drzgbr8TDN1=w80-h141-k-no'},
#  {'position': 3,
#   'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'place_id': 'ChIJ_UbCzYOLcC4R_zy6lNDVVhU',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'data_cid': '1537651414618750207',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0185885, 'longitude': 110.41940249999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b83cdc246fd%3A0x1556d5d094ba3cff%218m2%213d-7.0185885%214d110.41940249999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 2731,
#   'price': '$$',
#   'type': 'Steak house',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Candisari, Semarang City, Central Java 50232, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–11PM',
#    'sunday': '11AM–10PM',
#    'monday': '11AM–10PM'},
#   'phone': '+62 895-3549-91000',
#   'website': 'https://holycowsteak.com/',
#   'description': 'Restoran yg khusus menyajikan steak. Tempat makan yg menyajikan aneka pilihan daging berkualitas untuk steak, menerima panggilan kermh.',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPqPu4bqhe7bEBipPvmc-2Yi3pWSiXw7nfe4gOe=w163-h92-k-no'},
#  {'position': 4,
#   'title': 'STEAK ON THE STREET',
#   'place_id': 'ChIJ3bcbz7CNcC4Rm3lhyM7tzU0',
#   'data_id': '0x2e708db0cf1bb7dd:0x4dcdedcec861799b',
#   'data_cid': '5606398583527012763',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0396816, 'longitude': 110.4933362},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b%218m2%213d-7.0396816%214d110.4933362&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 5,
#   'reviews': 3,
#   'type': 'Steak house',
#   'address': 'Jl. Pucang Gading Raya No.104, Pucanggading, Batursari, Kec. Mranggen, Kabupaten Demak, Jawa Tengah 59567, Indonesia',
#   'open_state': 'Opens soon ⋅ 1PM',
#   'hours': 'Opens soon ⋅ 1PM',
#   'operating_hours': {'tuesday': '1–9PM',
#    'wednesday': '1–9PM',
#    'thursday': '1–9PM',
#    'friday': '1–9PM',
#    'saturday': '1–9PM',
#    'sunday': '1–9PM',
#    'monday': '1–9PM'},
#   'service_options': {'dine_in': True,
#    'drive_through': True,
#    'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoBouqPTUZvcPWyRMDJ6iiMkumZwei1Sz9KKmR=w163-h92-k-no'},
#  {'position': 5,
#   'title': 'Taman Sari Grilled Steak',
#   'place_id': 'ChIJB2uu93-LcC4RHEItlgp_X78',
#   'data_id': '0x2e708b7ff7ae6b07:0xbf5f7f0a962d421c',
#   'data_cid': '13789880267477697052',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0158051, 'longitude': 110.4256154},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c%218m2%213d-7.0158051%214d110.4256154&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 44,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'XCMG+M6H, Jl. Sisingamangaraja, Wonotingal, Kec. Candisari, Kota Semarang, Jawa Tengah 50525, Indonesia',
#   'open_state': 'Closed ⋅ Opens 4:30PM',
#   'hours': 'Closed ⋅ Opens 4:30PM',
#   'operating_hours': {'tuesday': '4:30–10PM',
#    'wednesday': '4:30–10PM',
#    'thursday': '4:30–10PM',
#    'friday': '4:30–10PM',
#    'saturday': '4:30–10PM',
#    'sunday': '4:30–10PM',
#    'monday': '4:30–10PM'},
#   'phone': '+62 812-2880-0077',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMIBpI0E2BiBfiDjiV0wgfgbl-PrO_ZnHpWlyuD=w122-h92-k-no'},
#  {'position': 6,
#   'title': 'Ins Steak House',
#   'place_id': 'ChIJw30Hzn-McC4Rw6s_u3UE-q8',
#   'data_id': '0x2e708c7fce077dc3:0xaffa0475bb3fabc3',
#   'data_cid': '12680452604514249667',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0174904, 'longitude': 110.4274169},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3%218m2%213d-7.0174904%214d110.4274169&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 6,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Dr. Wahidin No.92, Karanganyar Gunung, Candisari, Semarang City, Central Java 50253, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11AM–9PM'},
#   'phone': '+62 24 8310732',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEa34w2Qslkr037xNsf0EN_nTSyKcy6VhPcFIs=w80-h142-k-no'},
#  {'position': 7,
#   'title': 'So STEAK KENDAL',
#   'place_id': 'ChIJUXBXDGRdcC4R9CYZ14nMBzw',
#   'data_id': '0x2e705d640c577051:0x3c07cc89d71926f4',
#   'data_cid': '4325650859503986420',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9267803, 'longitude': 110.2071981},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e705d640c577051%3A0x3c07cc89d71926f4%218m2%213d-6.9267803%214d110.2071981&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 142,
#   'type': 'Restaurant',
#   'address': 'Kersan, Kebondalem, Kec. Kendal, Kabupaten Kendal, Jawa Tengah 51318, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': 'Closed'},
#   'phone': '+62 813-2949-2745',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPTe_Z-l8NMLqs2MSEHqNmY3KNuoLLrgmKu_C2d=w92-h92-k-no'},
#  {'position': 8,
#   'title': 'Star Steak',
#   'place_id': 'ChIJ5Z3wNmKLcC4RW933sUSOrjU',
#   'data_id': '0x2e708b6236f09de5:0x35ae8e44b1f7dd5b',
#   'data_cid': '3868185555652566363',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.010968999999999, 'longitude': 110.396046},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b%218m2%213d-7.010968999999999%214d110.396046&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 660,
#   'type': 'Steak house',
#   'address': 'Jl. Lamongan Raya No.12, Bendan Ngisor, Gajahmungkur, Semarang City, Central Java 50321, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '10AM–10PM',
#    'wednesday': '10AM–10PM',
#    'thursday': '10AM–10PM',
#    'friday': '10AM–10PM',
#    'saturday': '10AM–10PM',
#    'sunday': '10AM–10PM',
#    'monday': '10AM–10PM'},
#   'phone': '+62 858-8031-8858',
#   'website': 'https://starsteak-steakhouse.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP53s4hhDWTGrSUpbs4z7h5UrHVYdg07T3NkS7K=w194-h92-k-no'},
#  {'position': 9,
#   'title': 'Chicken Steak Crispy',
#   'place_id': 'ChIJ63e8DKaLcC4RI1wT2vMWTQA',
#   'data_id': '0x2e708ba60cbc77eb:0x4d16f3da135c23',
#   'data_cid': '21698809798286371',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9959221, 'longitude': 110.42092559999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba60cbc77eb%3A0x4d16f3da135c23%218m2%213d-6.9959221%214d110.42092559999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 15,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Pleburan Barat No.42, Pleburan, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50241, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNud-mXw04ejp8ArcZJXB_RDM2QpW7QnSGFjroI=w80-h142-k-no'},
#  {'position': 10,
#   'title': "MR FAT'S CHEESE STEAK",
#   'place_id': 'ChIJYQlJbsaMcC4Rl8VTYaRKD1g',
#   'data_id': '0x2e708cc66e490961:0x580f4aa46153c597',
#   'data_cid': '6345372469856290199',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9857739, 'longitude': 110.45514759999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cc66e490961%3A0x580f4aa46153c597%218m2%213d-6.9857739%214d110.45514759999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 22,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jalan Soekarno Hatta No.12 (Omah Jones), Kel. Tlogosari kulon , Kec. Gayamsari, Tlogosari Kulon, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50166, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 812-2622-7972',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Dg3XR_w3rqfIAftwT24KiA&cb_client=search.gws-prod.gps&w=80&h=92&yaw=188.40073&pitch=0&thumbfov=100'},
#  {'position': 11,
#   'title': 'beef steak spicy bolapelangi',
#   'place_id': 'ChIJL2aVRzuLcC4R6S8By3vLEaY',
#   'data_id': '0x2e708b3b4795662f:0xa611cb7bcb012fe9',
#   'data_cid': '11966569417447387113',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9809377999999995,
#    'longitude': 110.4244296},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b3b4795662f%3A0xa611cb7bcb012fe9%218m2%213d-6.9809377999999995%214d110.4244296&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': '2C9F+JQF, Gabahan, Semarang Tengah, Semarang City, Central Java 50135, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=A1zOu47mxt1eIuUUUf_Zrg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=19.593874&pitch=0&thumbfov=100'},
#  {'position': 12,
#   'title': 'Hans Steak',
#   'place_id': 'ChIJKwIlMECLcC4R6I8KGGzSs8w',
#   'data_id': '0x2e708b403025022b:0xccb3d26c180a8fe8',
#   'data_cid': '14750364566270152680',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9958234, 'longitude': 110.404715},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b403025022b%3A0xccb3d26c180a8fe8%218m2%213d-6.9958234%214d110.404715&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.8,
#   'reviews': 10,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C33+MVG, Jalan Kaligarang Raya, Barusari, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50244, Indonesia',
#   'open_state': 'Open ⋅ Closes 11PM',
#   'hours': 'Open ⋅ Closes 11PM',
#   'operating_hours': {'tuesday': '12–11PM',
#    'wednesday': '12–11PM',
#    'thursday': '12–11PM',
#    'friday': '12–11PM',
#    'saturday': '12–11PM',
#    'sunday': '12–11PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPm0c2HrgmNhi4-EjJIYQB2RgisVEa0V9XYXyEA=w99-h92-k-no'},
#  {'position': 13,
#   'title': 'jjsteak_therealsteak',
#   'place_id': 'ChIJpcSY1MmNcC4RqRhOAODVGpA',
#   'data_id': '0x2e708dc9d498c4a5:0x901ad5e0004e18a9',
#   'data_cid': '10383847048910608553',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9973417, 'longitude': 110.45581039999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9%218m2%213d-6.9973417%214d110.45581039999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 55,
#   'type': 'Steak house',
#   'address': 'Jl. Supriyadi No.20a, Kalicari, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50198, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–10PM',
#    'sunday': '11AM–10PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMSZ-QYnnSQC0scxmtfSHeMYXzvVaZMfMjU079o=w80-h106-k-no'},
#  {'position': 14,
#   'title': 'Royal Steak Citraland Mall',
#   'place_id': 'ChIJt_wE5ViLcC4RjATI-B32Jyo',
#   'data_id': '0x2e708b58e504fcb7:0x2a27f61df8c8048c',
#   'data_cid': '3037667082273031308',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.988728, 'longitude': 110.42369599999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b58e504fcb7%3A0x2a27f61df8c8048c%218m2%213d-6.988728%214d110.42369599999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.9,
#   'reviews': 13,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Mal Ciputra, Jalan simpang lima nomor 1, Citraland mall lantai 2, Food fair counter 11, Pekunden, Kec. Semarang Tengah, Kota Semarang, Jawa Tengah 50134, Indonesia',
#   'open_state': 'Open ⋅ Closes 9:30PM',
#   'hours': 'Open ⋅ Closes 9:30PM',
#   'operating_hours': {'tuesday': '9:30AM–9:30PM',
#    'wednesday': '9:30AM–9:30PM',
#    'thursday': '9:30AM–9:30PM',
#    'friday': '9:30AM–9:30PM',
#    'saturday': '9:30AM–9:30PM',
#    'sunday': '9:30AM–9:30PM',
#    'monday': '9:30AM–9:30PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPB23lKZAwvxQCERaBpIuz6rg-bNEMap3zWF1hm=w122-h92-k-no'},
#  {'position': 15,
#   'title': 'KhoKhu STEAK',
#   'place_id': 'ChIJ7WCwtwCMcC4REPjCbTl0_EM',
#   'data_id': '0x2e708c00b7b060ed:0x43fc74396dc2f810',
#   'data_cid': '4898918284675708944',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0232432, 'longitude': 110.4644659},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c00b7b060ed%3A0x43fc74396dc2f810%218m2%213d-7.0232432%214d110.4644659&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 229,
#   'type': 'Steak house',
#   'address': 'Jl. Gemah Jaya I, Kedungmundu, Tembalang, Semarang City, Central Java 50273, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '8AM–9PM',
#    'wednesday': '8AM–9PM',
#    'thursday': '8AM–9PM',
#    'friday': '8AM–9PM',
#    'saturday': '8AM–9PM',
#    'sunday': '8AM–9PM',
#    'monday': '8AM–9PM'},
#   'phone': '+62 878-7878-6241',
#   'website': 'https://www.facebook.com/khokhusteak.10414',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOCNTiV5n_8Ijv_Wrtqd1y2h9Xf_iCYutRzi6c=w204-h92-k-no'},
#  {'position': 16,
#   'title': 'Omah Steak',
#   'place_id': 'ChIJJYEA34uMcC4RdP6Tzg9iJu4',
#   'data_id': '0x2e708c8bdf008125:0xee26620fce93fe74',
#   'data_cid': '17160511250171690612',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0251882, 'longitude': 110.4602877},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c8bdf008125%3A0xee26620fce93fe74%218m2%213d-7.0251882%214d110.4602877&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': 'Jl. Kedungmundu No.19F, Kedungmundu, Kec. Tembalang, Kota Semarang, Jawa Tengah 50276, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=bbUS742SFXF7cOV2EGSCoQ&cb_client=search.gws-prod.gps&w=80&h=92&yaw=174.13599&pitch=0&thumbfov=100'},
#  {'position': 17,
#   'title': 'Steaky Steak Gajah Raya',
#   'place_id': 'ChIJk2lVeTqNcC4RbMlmYH1BwT0',
#   'data_id': '0x2e708d3a79556993:0x3dc1417d6066c96c',
#   'data_cid': '4449909913562827116',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9884702, 'longitude': 110.44835099999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708d3a79556993%3A0x3dc1417d6066c96c%218m2%213d-6.9884702%214d110.44835099999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 22,
#   'type': 'Steak house',
#   'address': 'Jl. Gajah Raya No.26 A, Siwalan, Kec. Gayamsari, Kota Semarang, Jawa Tengah 50262, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '12–9PM',
#    'wednesday': '12–9PM',
#    'thursday': '12–9PM',
#    'friday': '12–9PM',
#    'saturday': '12–9PM',
#    'sunday': '12–9PM',
#    'monday': '12–9PM'},
#   'phone': '+62 813-1923-4527',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOIkKZJDSPvlcWivR3-17C5g3zLTmLNBLkey-ic=w80-h142-k-no'},
#  {'position': 18,
#   'title': 'Omah Steak Qu',
#   'place_id': 'ChIJafZKkqiLcC4RfPs6n-p2Hgo',
#   'data_id': '0x2e708ba8924af669:0xa1e76ea9f3afb7c',
#   'data_cid': '729150939746466684',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9817195, 'longitude': 110.395702},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba8924af669%3A0xa1e76ea9f3afb7c%218m2%213d-6.9817195%214d110.395702&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 298,
#   'type': 'Steak house',
#   'address': 'Jl. Jenderal Sudirman, RT.001/RW.003, Cabean, Semarang Barat, Semarang City, Central Java 50141, Indonesia',
#   'open_state': 'Open ⋅ Closes 8PM',
#   'hours': 'Open ⋅ Closes 8PM',
#   'operating_hours': {'tuesday': '11:30AM–8PM',
#    'wednesday': '11:30AM–8PM',
#    'thursday': '11:30AM–8PM',
#    'friday': '11:30AM–8PM',
#    'saturday': '11:30AM–8PM',
#    'sunday': 'Closed',
#    'monday': '11:30AM–8PM'},
#   'phone': '+62 895-3270-76017',
#   'website': 'https://omah-steak-qu.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True,
#    'curbside_pickup': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipODaJ7qKrkRQMMtO9N0Y0e06RxjglhYzAlnwWty=w181-h92-k-no'},
#  {'position': 19,
#   'title': 'STAR STEAK',
#   'place_id': 'ChIJDbUrhDyJcC4RRPeD1oXmJ7g',
#   'data_id': '0x2e70893c842bb50d:0xb827e685d683f744',
#   'data_cid': '13269828289574467396',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0701481, 'longitude': 110.4219492},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e70893c842bb50d%3A0xb827e685d683f744%218m2%213d-7.0701481%214d110.4219492&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 318,
#   'type': 'Restaurant',
#   'address': 'Jl. Jati Raya No.25, Pedalangan, Kec. Banyumanik, Kota Semarang, Jawa Tengah 50268, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 858-8031-8858',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMYzqzTp4ybC6UGEn60Wbulm978VIWKlIw50Rgx=w199-h92-k-no'},
#  {'position': 20,
#   'title': 'Super steak jangli',
#   'place_id': 'ChIJgy7B1e2LcC4RhVj37ck6yEo',
#   'data_id': '0x2e708bedd5c12e83:0x4ac83ac9edf75885',
#   'data_cid': '5388621593104046213',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0275238, 'longitude': 110.424275},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708bedd5c12e83%3A0x4ac83ac9edf75885%218m2%213d-7.0275238%214d110.424275&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Fast food restaurant',
#   'address': 'Jl. Kesatrian rt003 No.h15, RW.008, Jatingaleh, Kec. Candisari, Kota Semarang, Jawa Tengah, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Alyg8hChtfhw9ZG82vRj_A&cb_client=search.gws-prod.gps&w=80&h=92&yaw=314.3858&pitch=0&thumbfov=100'}]

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  reviews = results["reviews"][i]["snippet"]
  print(reviews)
# Out:
# 4.0
# For steak with affordable price, the taste is pretty good. The place is pretty small. Prefer plating with normal plate, if use hotplate the meat would be a little overcooked. The food took a while to come out.
# 5.0
# Good taste. Good service. Affordable prices. Recommended.
# 5.0
# Cheap priced menu. . . Good and delicious sauce
# 5.0
# Worth it and better than the other one
# 5.0
# Good steak with a good price
# 5.0
# Nyusss
# 5.0
# Love it
# 5.0
# Good taste
# 5.0
# Ter the best
# 5.0
# Steak recommended 👍👍

# %%
#Posisi10
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708ba8924af669:0xa1e76ea9f3afb7c",
  "api_key": "704829de1a84ad99d46f48adbad6f986468a865efdfedaefe0a93de4d3e54e54"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Eatmeat Steak House',
#   'place_id': 'ChIJWYj5T66McC4RHa11Eq-lbvA',
#   'data_id': '0x2e708cae4ff98859:0xf06ea5af1275ad1d',
#   'data_cid': '17324966987888438557',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cae4ff98859%3A0xf06ea5af1275ad1d&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.981696599999999,
#    'longitude': 110.43589949999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cae4ff98859%3A0xf06ea5af1275ad1d%218m2%213d-6.981696599999999%214d110.43589949999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 3,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C9P+89C, Jl. Rejosari VII, Rejosari, Semarang Timur, Semarang City, Central Java 50125, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=UeSCBzPwdAhGcVhkBOLUhg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=334.76016&pitch=0&thumbfov=100'},
#  {'position': 2,
#   'title': 'Steaky Steak Sriwijaya Semarang',
#   'place_id': 'ChIJzxVGooKLcC4RiTjb6yLY4hA',
#   'data_id': '0x2e708b82a24615cf:0x10e2d822ebdb3889',
#   'data_cid': '1216772493840955529',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b82a24615cf%3A0x10e2d822ebdb3889&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.999720699999999,
#    'longitude': 110.42240489999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b82a24615cf%3A0x10e2d822ebdb3889%218m2%213d-6.999720699999999%214d110.42240489999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 84,
#   'type': 'Steak house',
#   'address': 'Jl. Sriwijaya No.16, Tegalsari, Kec. Candisari, Kota Semarang, Jawa Tengah 50614, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11:30AM–9PM',
#    'wednesday': '11:30AM–9PM',
#    'thursday': '11:30AM–9PM',
#    'friday': '11:30AM–9PM',
#    'saturday': '11:30AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11:30AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN-q1TtYM39l_8VnZ8yPjC0wkfL-Drzgbr8TDN1=w80-h141-k-no'},
#  {'position': 3,
#   'title': 'Steak Hotel by HOLYCOW! TKP Semarang',
#   'place_id': 'ChIJ_UbCzYOLcC4R_zy6lNDVVhU',
#   'data_id': '0x2e708b83cdc246fd:0x1556d5d094ba3cff',
#   'data_cid': '1537651414618750207',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b83cdc246fd%3A0x1556d5d094ba3cff&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0185885, 'longitude': 110.41940249999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b83cdc246fd%3A0x1556d5d094ba3cff%218m2%213d-7.0185885%214d110.41940249999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 2731,
#   'price': '$$',
#   'type': 'Steak house',
#   'address': 'Jl. Sultan Agung No.142, Kaliwiru, Candisari, Semarang City, Central Java 50232, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–11PM',
#    'sunday': '11AM–10PM',
#    'monday': '11AM–10PM'},
#   'phone': '+62 895-3549-91000',
#   'website': 'https://holycowsteak.com/',
#   'description': 'Restoran yg khusus menyajikan steak. Tempat makan yg menyajikan aneka pilihan daging berkualitas untuk steak, menerima panggilan kermh.',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPqPu4bqhe7bEBipPvmc-2Yi3pWSiXw7nfe4gOe=w163-h92-k-no'},
#  {'position': 4,
#   'title': 'STEAK ON THE STREET',
#   'place_id': 'ChIJ3bcbz7CNcC4Rm3lhyM7tzU0',
#   'data_id': '0x2e708db0cf1bb7dd:0x4dcdedcec861799b',
#   'data_cid': '5606398583527012763',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0396816, 'longitude': 110.4933362},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708db0cf1bb7dd%3A0x4dcdedcec861799b%218m2%213d-7.0396816%214d110.4933362&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 5,
#   'reviews': 3,
#   'type': 'Steak house',
#   'address': 'Jl. Pucang Gading Raya No.104, Pucanggading, Batursari, Kec. Mranggen, Kabupaten Demak, Jawa Tengah 59567, Indonesia',
#   'open_state': 'Opens soon ⋅ 1PM',
#   'hours': 'Opens soon ⋅ 1PM',
#   'operating_hours': {'tuesday': '1–9PM',
#    'wednesday': '1–9PM',
#    'thursday': '1–9PM',
#    'friday': '1–9PM',
#    'saturday': '1–9PM',
#    'sunday': '1–9PM',
#    'monday': '1–9PM'},
#   'service_options': {'dine_in': True,
#    'drive_through': True,
#    'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoBouqPTUZvcPWyRMDJ6iiMkumZwei1Sz9KKmR=w163-h92-k-no'},
#  {'position': 5,
#   'title': 'Taman Sari Grilled Steak',
#   'place_id': 'ChIJB2uu93-LcC4RHEItlgp_X78',
#   'data_id': '0x2e708b7ff7ae6b07:0xbf5f7f0a962d421c',
#   'data_cid': '13789880267477697052',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0158051, 'longitude': 110.4256154},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b7ff7ae6b07%3A0xbf5f7f0a962d421c%218m2%213d-7.0158051%214d110.4256154&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 44,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'XCMG+M6H, Jl. Sisingamangaraja, Wonotingal, Kec. Candisari, Kota Semarang, Jawa Tengah 50525, Indonesia',
#   'open_state': 'Closed ⋅ Opens 4:30PM',
#   'hours': 'Closed ⋅ Opens 4:30PM',
#   'operating_hours': {'tuesday': '4:30–10PM',
#    'wednesday': '4:30–10PM',
#    'thursday': '4:30–10PM',
#    'friday': '4:30–10PM',
#    'saturday': '4:30–10PM',
#    'sunday': '4:30–10PM',
#    'monday': '4:30–10PM'},
#   'phone': '+62 812-2880-0077',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMIBpI0E2BiBfiDjiV0wgfgbl-PrO_ZnHpWlyuD=w122-h92-k-no'},
#  {'position': 6,
#   'title': 'Ins Steak House',
#   'place_id': 'ChIJw30Hzn-McC4Rw6s_u3UE-q8',
#   'data_id': '0x2e708c7fce077dc3:0xaffa0475bb3fabc3',
#   'data_cid': '12680452604514249667',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0174904, 'longitude': 110.4274169},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c7fce077dc3%3A0xaffa0475bb3fabc3%218m2%213d-7.0174904%214d110.4274169&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 6,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Dr. Wahidin No.92, Karanganyar Gunung, Candisari, Semarang City, Central Java 50253, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11:30AM–9PM',
#    'monday': '11AM–9PM'},
#   'phone': '+62 24 8310732',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEa34w2Qslkr037xNsf0EN_nTSyKcy6VhPcFIs=w80-h142-k-no'},
#  {'position': 7,
#   'title': 'So STEAK KENDAL',
#   'place_id': 'ChIJUXBXDGRdcC4R9CYZ14nMBzw',
#   'data_id': '0x2e705d640c577051:0x3c07cc89d71926f4',
#   'data_cid': '4325650859503986420',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e705d640c577051%3A0x3c07cc89d71926f4&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9267803, 'longitude': 110.2071981},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e705d640c577051%3A0x3c07cc89d71926f4%218m2%213d-6.9267803%214d110.2071981&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 142,
#   'type': 'Restaurant',
#   'address': 'Kersan, Kebondalem, Kec. Kendal, Kabupaten Kendal, Jawa Tengah 51318, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': 'Closed'},
#   'phone': '+62 813-2949-2745',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPTe_Z-l8NMLqs2MSEHqNmY3KNuoLLrgmKu_C2d=w92-h92-k-no'},
#  {'position': 8,
#   'title': 'Star Steak',
#   'place_id': 'ChIJ5Z3wNmKLcC4RW933sUSOrjU',
#   'data_id': '0x2e708b6236f09de5:0x35ae8e44b1f7dd5b',
#   'data_cid': '3868185555652566363',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.010968999999999, 'longitude': 110.396046},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b6236f09de5%3A0x35ae8e44b1f7dd5b%218m2%213d-7.010968999999999%214d110.396046&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 660,
#   'type': 'Steak house',
#   'address': 'Jl. Lamongan Raya No.12, Bendan Ngisor, Gajahmungkur, Semarang City, Central Java 50321, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '10AM–10PM',
#    'wednesday': '10AM–10PM',
#    'thursday': '10AM–10PM',
#    'friday': '10AM–10PM',
#    'saturday': '10AM–10PM',
#    'sunday': '10AM–10PM',
#    'monday': '10AM–10PM'},
#   'phone': '+62 858-8031-8858',
#   'website': 'https://starsteak-steakhouse.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP53s4hhDWTGrSUpbs4z7h5UrHVYdg07T3NkS7K=w194-h92-k-no'},
#  {'position': 9,
#   'title': 'Chicken Steak Crispy',
#   'place_id': 'ChIJ63e8DKaLcC4RI1wT2vMWTQA',
#   'data_id': '0x2e708ba60cbc77eb:0x4d16f3da135c23',
#   'data_cid': '21698809798286371',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba60cbc77eb%3A0x4d16f3da135c23&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9959221, 'longitude': 110.42092559999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba60cbc77eb%3A0x4d16f3da135c23%218m2%213d-6.9959221%214d110.42092559999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.3,
#   'reviews': 15,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jl. Pleburan Barat No.42, Pleburan, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50241, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNud-mXw04ejp8ArcZJXB_RDM2QpW7QnSGFjroI=w80-h142-k-no'},
#  {'position': 10,
#   'title': "MR FAT'S CHEESE STEAK",
#   'place_id': 'ChIJYQlJbsaMcC4Rl8VTYaRKD1g',
#   'data_id': '0x2e708cc66e490961:0x580f4aa46153c597',
#   'data_cid': '6345372469856290199',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708cc66e490961%3A0x580f4aa46153c597&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9857739, 'longitude': 110.45514759999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708cc66e490961%3A0x580f4aa46153c597%218m2%213d-6.9857739%214d110.45514759999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4,
#   'reviews': 22,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Jalan Soekarno Hatta No.12 (Omah Jones), Kel. Tlogosari kulon , Kec. Gayamsari, Tlogosari Kulon, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50166, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 812-2622-7972',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Dg3XR_w3rqfIAftwT24KiA&cb_client=search.gws-prod.gps&w=80&h=92&yaw=188.40073&pitch=0&thumbfov=100'},
#  {'position': 11,
#   'title': 'beef steak spicy bolapelangi',
#   'place_id': 'ChIJL2aVRzuLcC4R6S8By3vLEaY',
#   'data_id': '0x2e708b3b4795662f:0xa611cb7bcb012fe9',
#   'data_cid': '11966569417447387113',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b3b4795662f%3A0xa611cb7bcb012fe9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9809377999999995,
#    'longitude': 110.4244296},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b3b4795662f%3A0xa611cb7bcb012fe9%218m2%213d-6.9809377999999995%214d110.4244296&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': '2C9F+JQF, Gabahan, Semarang Tengah, Semarang City, Central Java 50135, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=A1zOu47mxt1eIuUUUf_Zrg&cb_client=search.gws-prod.gps&w=80&h=92&yaw=19.593874&pitch=0&thumbfov=100'},
#  {'position': 12,
#   'title': 'Hans Steak',
#   'place_id': 'ChIJKwIlMECLcC4R6I8KGGzSs8w',
#   'data_id': '0x2e708b403025022b:0xccb3d26c180a8fe8',
#   'data_cid': '14750364566270152680',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b403025022b%3A0xccb3d26c180a8fe8&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9958234, 'longitude': 110.404715},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b403025022b%3A0xccb3d26c180a8fe8%218m2%213d-6.9958234%214d110.404715&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.8,
#   'reviews': 10,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': '2C33+MVG, Jalan Kaligarang Raya, Barusari, Kec. Semarang Sel., Kota Semarang, Jawa Tengah 50244, Indonesia',
#   'open_state': 'Open ⋅ Closes 11PM',
#   'hours': 'Open ⋅ Closes 11PM',
#   'operating_hours': {'tuesday': '12–11PM',
#    'wednesday': '12–11PM',
#    'thursday': '12–11PM',
#    'friday': '12–11PM',
#    'saturday': '12–11PM',
#    'sunday': '12–11PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPm0c2HrgmNhi4-EjJIYQB2RgisVEa0V9XYXyEA=w99-h92-k-no'},
#  {'position': 13,
#   'title': 'jjsteak_therealsteak',
#   'place_id': 'ChIJpcSY1MmNcC4RqRhOAODVGpA',
#   'data_id': '0x2e708dc9d498c4a5:0x901ad5e0004e18a9',
#   'data_cid': '10383847048910608553',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9973417, 'longitude': 110.45581039999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708dc9d498c4a5%3A0x901ad5e0004e18a9%218m2%213d-6.9973417%214d110.45581039999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 55,
#   'type': 'Steak house',
#   'address': 'Jl. Supriyadi No.20a, Kalicari, Kec. Pedurungan, Kota Semarang, Jawa Tengah 50198, Indonesia',
#   'open_state': 'Open ⋅ Closes 10PM',
#   'hours': 'Open ⋅ Closes 10PM',
#   'operating_hours': {'tuesday': '11AM–10PM',
#    'wednesday': '11AM–10PM',
#    'thursday': '11AM–10PM',
#    'friday': '11AM–10PM',
#    'saturday': '11AM–10PM',
#    'sunday': '11AM–10PM',
#    'monday': 'Closed'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMSZ-QYnnSQC0scxmtfSHeMYXzvVaZMfMjU079o=w80-h106-k-no'},
#  {'position': 14,
#   'title': 'Royal Steak Citraland Mall',
#   'place_id': 'ChIJt_wE5ViLcC4RjATI-B32Jyo',
#   'data_id': '0x2e708b58e504fcb7:0x2a27f61df8c8048c',
#   'data_cid': '3037667082273031308',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b58e504fcb7%3A0x2a27f61df8c8048c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.988728, 'longitude': 110.42369599999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b58e504fcb7%3A0x2a27f61df8c8048c%218m2%213d-6.988728%214d110.42369599999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 3.9,
#   'reviews': 13,
#   'unclaimed_listing': True,
#   'type': 'Steak house',
#   'address': 'Mal Ciputra, Jalan simpang lima nomor 1, Citraland mall lantai 2, Food fair counter 11, Pekunden, Kec. Semarang Tengah, Kota Semarang, Jawa Tengah 50134, Indonesia',
#   'open_state': 'Open ⋅ Closes 9:30PM',
#   'hours': 'Open ⋅ Closes 9:30PM',
#   'operating_hours': {'tuesday': '9:30AM–9:30PM',
#    'wednesday': '9:30AM–9:30PM',
#    'thursday': '9:30AM–9:30PM',
#    'friday': '9:30AM–9:30PM',
#    'saturday': '9:30AM–9:30PM',
#    'sunday': '9:30AM–9:30PM',
#    'monday': '9:30AM–9:30PM'},
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPB23lKZAwvxQCERaBpIuz6rg-bNEMap3zWF1hm=w122-h92-k-no'},
#  {'position': 15,
#   'title': 'KhoKhu STEAK',
#   'place_id': 'ChIJ7WCwtwCMcC4REPjCbTl0_EM',
#   'data_id': '0x2e708c00b7b060ed:0x43fc74396dc2f810',
#   'data_cid': '4898918284675708944',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c00b7b060ed%3A0x43fc74396dc2f810&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0232432, 'longitude': 110.4644659},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c00b7b060ed%3A0x43fc74396dc2f810%218m2%213d-7.0232432%214d110.4644659&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.6,
#   'reviews': 229,
#   'type': 'Steak house',
#   'address': 'Jl. Gemah Jaya I, Kedungmundu, Tembalang, Semarang City, Central Java 50273, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '8AM–9PM',
#    'wednesday': '8AM–9PM',
#    'thursday': '8AM–9PM',
#    'friday': '8AM–9PM',
#    'saturday': '8AM–9PM',
#    'sunday': '8AM–9PM',
#    'monday': '8AM–9PM'},
#   'phone': '+62 878-7878-6241',
#   'website': 'https://www.facebook.com/khokhusteak.10414',
#   'service_options': {'dine_in': True, 'takeout': True, 'delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOCNTiV5n_8Ijv_Wrtqd1y2h9Xf_iCYutRzi6c=w204-h92-k-no'},
#  {'position': 16,
#   'title': 'Omah Steak',
#   'place_id': 'ChIJJYEA34uMcC4RdP6Tzg9iJu4',
#   'data_id': '0x2e708c8bdf008125:0xee26620fce93fe74',
#   'data_cid': '17160511250171690612',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708c8bdf008125%3A0xee26620fce93fe74&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0251882, 'longitude': 110.4602877},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708c8bdf008125%3A0xee26620fce93fe74%218m2%213d-7.0251882%214d110.4602877&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Restaurant',
#   'address': 'Jl. Kedungmundu No.19F, Kedungmundu, Kec. Tembalang, Kota Semarang, Jawa Tengah 50276, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '11AM–9PM',
#    'wednesday': '11AM–9PM',
#    'thursday': '11AM–9PM',
#    'friday': '11AM–9PM',
#    'saturday': '11AM–9PM',
#    'sunday': '11AM–9PM',
#    'monday': '11AM–9PM'},
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=bbUS742SFXF7cOV2EGSCoQ&cb_client=search.gws-prod.gps&w=80&h=92&yaw=174.13599&pitch=0&thumbfov=100'},
#  {'position': 17,
#   'title': 'Steaky Steak Gajah Raya',
#   'place_id': 'ChIJk2lVeTqNcC4RbMlmYH1BwT0',
#   'data_id': '0x2e708d3a79556993:0x3dc1417d6066c96c',
#   'data_cid': '4449909913562827116',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708d3a79556993%3A0x3dc1417d6066c96c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9884702, 'longitude': 110.44835099999999},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708d3a79556993%3A0x3dc1417d6066c96c%218m2%213d-6.9884702%214d110.44835099999999&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 22,
#   'type': 'Steak house',
#   'address': 'Jl. Gajah Raya No.26 A, Siwalan, Kec. Gayamsari, Kota Semarang, Jawa Tengah 50262, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '12–9PM',
#    'wednesday': '12–9PM',
#    'thursday': '12–9PM',
#    'friday': '12–9PM',
#    'saturday': '12–9PM',
#    'sunday': '12–9PM',
#    'monday': '12–9PM'},
#   'phone': '+62 813-1923-4527',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOIkKZJDSPvlcWivR3-17C5g3zLTmLNBLkey-ic=w80-h142-k-no'},
#  {'position': 18,
#   'title': 'Omah Steak Qu',
#   'place_id': 'ChIJafZKkqiLcC4RfPs6n-p2Hgo',
#   'data_id': '0x2e708ba8924af669:0xa1e76ea9f3afb7c',
#   'data_cid': '729150939746466684',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708ba8924af669%3A0xa1e76ea9f3afb7c&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9817195, 'longitude': 110.395702},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708ba8924af669%3A0xa1e76ea9f3afb7c%218m2%213d-6.9817195%214d110.395702&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.7,
#   'reviews': 298,
#   'type': 'Steak house',
#   'address': 'Jl. Jenderal Sudirman, RT.001/RW.003, Cabean, Semarang Barat, Semarang City, Central Java 50141, Indonesia',
#   'open_state': 'Open ⋅ Closes 8PM',
#   'hours': 'Open ⋅ Closes 8PM',
#   'operating_hours': {'tuesday': '11:30AM–8PM',
#    'wednesday': '11:30AM–8PM',
#    'thursday': '11:30AM–8PM',
#    'friday': '11:30AM–8PM',
#    'saturday': '11:30AM–8PM',
#    'sunday': 'Closed',
#    'monday': '11:30AM–8PM'},
#   'phone': '+62 895-3270-76017',
#   'website': 'https://omah-steak-qu.business.site/?utm_source=gmb&utm_medium=referral',
#   'service_options': {'dine_in': True,
#    'curbside_pickup': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipODaJ7qKrkRQMMtO9N0Y0e06RxjglhYzAlnwWty=w181-h92-k-no'},
#  {'position': 19,
#   'title': 'STAR STEAK',
#   'place_id': 'ChIJDbUrhDyJcC4RRPeD1oXmJ7g',
#   'data_id': '0x2e70893c842bb50d:0xb827e685d683f744',
#   'data_cid': '13269828289574467396',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e70893c842bb50d%3A0xb827e685d683f744&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0701481, 'longitude': 110.4219492},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e70893c842bb50d%3A0xb827e685d683f744%218m2%213d-7.0701481%214d110.4219492&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.4,
#   'reviews': 318,
#   'type': 'Restaurant',
#   'address': 'Jl. Jati Raya No.25, Pedalangan, Kec. Banyumanik, Kota Semarang, Jawa Tengah 50268, Indonesia',
#   'open_state': 'Open ⋅ Closes 9PM',
#   'hours': 'Open ⋅ Closes 9PM',
#   'operating_hours': {'tuesday': '10AM–9PM',
#    'wednesday': '10AM–9PM',
#    'thursday': '10AM–9PM',
#    'friday': '10AM–9PM',
#    'saturday': '10AM–9PM',
#    'sunday': '10AM–9PM',
#    'monday': '10AM–9PM'},
#   'phone': '+62 858-8031-8858',
#   'service_options': {'dine_in': True,
#    'takeout': True,
#    'no_contact_delivery': True},
#   'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMYzqzTp4ybC6UGEn60Wbulm978VIWKlIw50Rgx=w199-h92-k-no'},
#  {'position': 20,
#   'title': 'Super steak jangli',
#   'place_id': 'ChIJgy7B1e2LcC4RhVj37ck6yEo',
#   'data_id': '0x2e708bedd5c12e83:0x4ac83ac9edf75885',
#   'data_cid': '5388621593104046213',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708bedd5c12e83%3A0x4ac83ac9edf75885&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -7.0275238, 'longitude': 110.424275},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708bedd5c12e83%3A0x4ac83ac9edf75885%218m2%213d-7.0275238%214d110.424275&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'unclaimed_listing': True,
#   'type': 'Fast food restaurant',
#   'address': 'Jl. Kesatrian rt003 No.h15, RW.008, Jatingaleh, Kec. Candisari, Kota Semarang, Jawa Tengah, Indonesia',
#   'service_options': {'dine_in': True, 'takeout': True},
#   'thumbnail': 'https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=Alyg8hChtfhw9ZG82vRj_A&cb_client=search.gws-prod.gps&w=80&h=92&yaw=314.3858&pitch=0&thumbfov=100'}]

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  reviews = results["reviews"][i]["snippet"]
  print(reviews)
# Out:
# 3.0
# The taste of the dishes is not bad, except the tiny portion . The price was okay when we got 30% discount during the opening month
# 5.0
# good food, comfortable place, very satisfying. delicious steak semarang. really recommend
# 5.0
# good taste and very good service to customers. Lots of delicious and quality dishes on the menu
# 5.0
# Great food with moderate price but limited parking space for car
# 5.0
# Ok
# 5.0
# Ok
# 5.0
# Ok
# 5.0
# Ok
# 5.0
# Ok
# 5.0
# Ok

# %%
#===Text Processing===
#Case Folding
#1. Menghapus Tanda Baca

import string
kalimat = "Steak lover's musti coba....dijamin ketagihan..🤩🤩🤩🤩"
hasil = kalimat.translate(str.maketrans("","",string.punctuation))
print(hasil)
# Out:
# Steak lovers musti cobadijamin ketagihan🤩🤩🤩🤩

# %%
#Tokenizing
import nltk
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize 
kalimat = "Makanan enak, tempat bersih,"
kalimat=kalimat+" pelayanan baik, harga bersahabat"
tokens = word_tokenize(kalimat)
print(tokens)#
# Out:
# ['Makanan', 'enak', ',', 'tempat', 'bersih', ',', 'pelayanan', 'baik', ',', 'harga', 'bersahabat']

# %%
#=== Filtering (Stopword Removal)===
#1.Filtering Dengan Sastrawi
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 9.7 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# Daftar stopword yang tersedia di library Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %%
# imort StopWordRemoverFactory clas
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
#Kalimat
kalimat = "Makan steak ini dr dulu jaman pacaran mgkn lbh dr 10 tahun lalu..salisbury is the best...walaupun kaki lima rasa ga boleh disepelin..enak aku rasa mantan chef atau kerja resto deh dulu hehhe..harga steak sekitar 28 sampai 52..ada juga sop iga..n spagethi"
stop = stopword.remove(kalimat)
print(stop)
# Out:
# Makan steak dr dulu jaman pacaran mgkn lbh dr 10 tahun lalu..salisbury is the best...walaupun kaki lima rasa ga disepelin..enak aku rasa mantan chef kerja resto deh dulu hehhe..harga steak 28 52..ada sop iga..n spagethi

# %%
#===Stemming===
#Stemming dengan sastrawi
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
# import StemmerFactory class
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
kalimat = 'Masya Allah wenak banget steaknya kak.. 🙏 Saking enaknya sampe ga motret makanannya. Insya Allah kesini lagi mau cobain menu yang lain. Sukses ya, mudah2an laris dan rame 💕 Buat yang belum pernah coba, silakan mampir kesini, sesekali makan steak di kaki lima'
hasil = stemmer.stem(kalimat)
print(hasil)
# Out:
# masya allah wenak banget steaknya kak saking enak sampe ga motret makan insya allah kesini lagi mau cobain menu yang lain sukses ya mudah2an laris dan rame buat yang belum pernah coba sila mampir kesini sekal makan steak di kaki lima
